# %% [markdown]
# # 나이브베이즈 분류
# * 베이즈 이론(베이지안 확률)
#   * A가 일어났을 때 B가 일어날 확률
#   * 메일 제목에 '무료'라는 단어가 들어있을 때 스팸 메일일 확률
#   * 주관적으로 확률을 해석
#   * 데이터를 통해서 확률을 추정할 때 현재 관측된 데이터의 빈도만으로 분석하는 것이 아니라 분석자의 사전지식(혹의 알려진 사실, 분석자의 주관)까지 포함해 분석하는 방법
#   * 베이즈 정리에서 확률은 '주장'혹은 '믿음의 신뢰도'로 나타난다.
# * 나이브 베이즈 분류 모델은 베이즈 정리를 기반으로 한 지도학습 모델로, 스펨 메일 필터링, 텍스트 분류 등에 사용된다.
# * 나이브 베이즈는 데이터의 모든 특성 변수가 서로 동등하고 독립적이라는 가정하에 분류를 실행한다.
# * 독립 변수의 특성들은 나이브 베이즈 분류기에서 서로 연관성이 없고, 각각의 특성이 독립적으로 기여하는 것으로 간주한다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/advertising.csv")
data.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     68.95   NaN     61833.90                256.09
# 1                     80.23  31.0     68441.85                193.77
# 2                     69.47  26.0     59785.94                236.50
# 3                     74.15  29.0     54806.18                245.89
# 4                     68.37  35.0     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#          Timestamp  Clicked on Ad
# 0   3/27/2016 0:53              0
# 1    4/4/2016 1:39              0
# 2  3/13/2016 20:35              0
# 3   1/10/2016 2:31              0
# 4    6/3/2016 3:36              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       916 non-null    float64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 78.2+ KB

# %%
data.isna().sum()
# Out:
# Daily Time Spent on Site     0
# Age                         84
# Area Income                  0
# Daily Internet Usage         0
# Ad Topic Line                0
# City                         0
# Male                         0
# Country                      0
# Timestamp                    0
# Clicked on Ad                0
# dtype: int64

# %%
data.groupby('Age')['Clicked on Ad'].value_counts()
# Out:
# Age   Clicked on Ad
# 19.0  0                5
#       1                1
# 20.0  0                5
#       1                1
# 21.0  0                5
#                       ..
# 57.0  1                6
# 58.0  1                4
# 59.0  1                2
# 60.0  1                4
# 61.0  1                1
# Name: count, Length: 76, dtype: int64

# %%
data2 = data[data['Age'].isna() == False]

# %%
data2['Age'].describe()
# Out:
# count    916.000000
# mean      36.128821
# std        9.018548
# min       19.000000
# 25%       29.000000
# 50%       35.000000
# 75%       42.000000
# max       61.000000
# Name: Age, dtype: float64

# %%
def ages(x):
    if x < 20:
        return '10s'
    elif 20 <= x < 30:
        return '20s'
    elif 30 <= x < 40:
        return '30s'
    elif 40 <= x < 50:
        return '40s'
    elif 50 <= x < 60:
        return '50s'
    elif 60 <= x < 70:
        return '60s'

# %%
data2['Age'] = data2['Age'].apply(ages)
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_14072\3509914117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Age'] = data2['Age'].apply(ages)

# %%
data2.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 1                     80.23  30s     68441.85                193.77
# 2                     69.47  20s     59785.94                236.50
# 3                     74.15  20s     54806.18                245.89
# 4                     68.37  30s     73889.99                225.58
# 5                     59.99  20s     59761.56                226.74
#
#                            Ad Topic Line            City  Male     Country  \
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
# 5        Sharable client-driven software       Jamieberg     1      Norway
#
#          Timestamp  Clicked on Ad
# 1    4/4/2016 1:39              0
# 2  3/13/2016 20:35              0
# 3   1/10/2016 2:31              0
# 4    6/3/2016 3:36              0
# 5  5/19/2016 14:30              0

# %%
data2.groupby('Age')['Clicked on Ad'].value_counts(sort=False)
# Out:
# Age  Clicked on Ad
# 10s  0                  5
#      1                  1
# 20s  0                183
#      1                 61
# 30s  0                211
#      1                143
# 40s  0                 51
#      1                169
# 50s  0                  4
#      1                 83
# 60s  1                  5
# Name: count, dtype: int64

# %%
data2.loc[data2['Age'] == '50s', 'Ad Topic Line']
# Out:
# 22           Mandatory disintermediate utilization
# 27                  Monitored systematic hierarchy
# 32                     Digitized global capability
# 34             Synchronized dedicated service-desk
# 36                         Profound stable product
#                           ...
# 965                       Intuitive global website
# 966    Exclusive disintermediate Internet solution
# 972                   Switchable real-time product
# 980          Focused incremental Graphic Interface
# 997                   Expanded intangible solution
# Name: Ad Topic Line, Length: 87, dtype: object

# %%
data.loc[(data['Age'].isna() == True) & (data['Clicked on Ad'] == 1)]
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 18                      54.70  NaN     31087.54                118.39
# 56                      65.19  NaN     75254.88                150.61
# 96                      45.72  NaN     22473.08                154.02
# 156                     44.64  NaN     55787.58                127.01
# 189                     39.86  NaN     32593.59                145.85
# 219                     43.60  NaN     20856.54                170.49
# 231                     46.77  NaN     31092.93                136.40
# 232                     62.42  NaN     74445.18                143.94
# 282                     40.67  NaN     48913.07                133.18
# 302                     39.25  NaN     62378.05                152.36
# 303                     77.56  NaN     63336.85                130.83
# 357                     49.84  NaN     45800.48                111.59
# 389                     63.88  NaN     19991.72                136.85
# 450                     43.41  NaN     59144.02                160.73
# 451                     55.92  NaN     33951.63                145.08
# 488                     35.49  NaN     43974.49                159.77
# 490                     50.19  NaN     33987.27                117.30
# 491                     59.12  NaN     28210.03                124.54
# 561                     38.35  NaN     34886.01                144.69
# 564                     64.75  NaN     63001.03                117.66
# 616                     52.70  NaN     41059.64                109.34
# 618                     35.55  NaN     51593.46                151.18
# 665                     58.05  NaN     15879.10                195.54
# 668                     52.56  NaN     33147.19                250.36
# 715                     49.19  NaN     61004.51                123.08
# 716                     39.96  NaN     53898.89                138.52
# 780                     67.85  NaN     78520.99                202.70
# 781                     75.55  NaN     31998.72                123.71
# 828                     66.69  NaN     48758.92                108.27
# 829                     48.46  NaN     61230.03                132.38
# 830                     42.51  NaN     54755.71                144.77
# 831                     42.83  NaN     54324.73                132.38
# 832                     41.46  NaN     52177.40                128.98
# 876                     67.39  NaN     51257.26                107.19
# 929                     82.49  NaN     38645.40                130.84
# 931                     61.76  NaN     33553.90                114.69
# 932                     63.30  NaN     63071.34                116.19
# 960                     56.78  NaN     39939.39                124.32
#
#                                         Ad Topic Line                 City  \
# 18       Grass-roots solution-oriented conglomeration          Jessicastad
# 56                       Cross-group regional website           Garciaside
# 96                     Versatile homogeneous capacity         Williammouth
# 156                   Up-sized incremental encryption            Codyburgh
# 189               Total 5thgeneration standardization           Josephstad
# 219            Virtual bandwidth-monitored initiative    North Ricardotown
# 231                    Multi-tiered maximized archive         Reneechester
# 232                       Diverse executive groupware       West Tinashire
# 282               Stand-alone encompassing throughput          West Amanda
# 302        Customer-focused incremental system engine         Michellefort
# 303                Right-sized multi-tasking solution     Port Angelamouth
# 357                        Reduced multimedia project            Hannaport
# 389                   Upgradable even-keeled hardware          Kristintown
# 450  Customer-focused zero-defect process improvement            Lovemouth
# 451                        Focused systemic benchmark          Taylorhaven
# 488            Fully-configurable holistic throughput          Timothyport
# 490          Progressive uniform budgetary management  Lake Stephenborough
# 491                 Synergistic stable infrastructure             Silvaton
# 561                   Synergistic reciprocal attitude            Loriville
# 564                      Multi-tiered stable leverage      North Sarashire
# 616            Team-oriented high-level orchestration          New Matthew
# 618          Robust object-oriented Graphic Interface            Westshire
# 665                   Total asynchronous architecture          Sanderstown
# 668                    Integrated interactive support        New Karenberg
# 715          Versatile solution-oriented secured line           North Mark
# 716           Phased leadingedge budgetary management          Kingchester
# 780                     Reactive tangible contingency          East Ronald
# 781         Decentralized attitude-oriented interface     South Davidmouth
# 828                   Integrated encompassing support          Vanessastad
# 829                   Devolved human-resource circuit            Lisamouth
# 830              Grass-roots transitional flexibility     Lake Rhondaburgh
# 831                Vision-oriented methodical support      Cunninghamhaven
# 832                    Integrated impactful groupware          Robertstown
# 876                Realigned intermediate application           Josephberg
# 929                  Assimilated multi-state paradigm         Williamsfort
# 931                        Open-source local approach          Edwardsport
# 932                     Polarized intangible encoding        Lake Evantown
# 960                  Mandatory empowering focus group           Melanieton
#
#      Male                                            Country        Timestamp  \
# 18      1  British Indian Ocean Territory (Chagos Archipe...   2/13/2016 7:53
# 56      0                                             Israel  2/17/2016 11:42
# 96      1                                          Hong Kong  4/19/2016 15:14
# 156     0                                             Belize   2/14/2016 6:51
# 189     0                                            Algeria  6/26/2016 17:16
# 219     0                                              Chile   1/11/2016 7:36
# 231     1                                             Serbia   3/23/2016 6:00
# 232     0                          Saint Pierre and Miquelon   7/19/2016 7:59
# 282     0                                            Lebanon    5/5/2016 9:28
# 302     0                                            Mayotte  1/23/2016 17:39
# 303     1                                             Uganda   5/19/2016 3:52
# 357     0                                              Samoa    2/9/2016 7:21
# 389     0                                         Madagascar  2/29/2016 23:56
# 450     0                                              Egypt   2/5/2016 15:26
# 451     0                                               Fiji  5/31/2016 21:41
# 488     0                                     American Samoa   4/8/2016 14:35
# 490     0                                           Thailand  3/25/2016 19:02
# 491     0                                             Greece  5/12/2016 21:32
# 561     1                                            Vanuatu   6/24/2016 8:42
# 564     0                                          Venezuela    4/6/2016 1:19
# 616     1                                             Zambia   1/31/2016 8:50
# 618     0                                         Micronesia  1/13/2016 20:38
# 665     1                                         Tajikistan  2/12/2016 10:39
# 668     1                                             Israel   4/24/2016 1:48
# 715     0                                            Hungary  5/12/2016 12:11
# 716     1                                   Pitcairn Islands  2/28/2016 23:21
# 780     1                                       Saint Helena  1/21/2016 22:51
# 781     1                             Bosnia and Herzegovina   3/12/2016 6:05
# 828     0                                             Jersey  5/11/2016 19:13
# 829     1                                          Indonesia  1/21/2016 23:33
# 830     1                              Palestinian Territory  1/15/2016 19:45
# 831     1                                             Latvia   4/23/2016 9:42
# 832     1                                              Malta   5/23/2016 8:06
# 876     0                                            Armenia  1/24/2016 13:41
# 929     0                                 Dominican Republic   5/31/2016 0:58
# 931     0                                            Jamaica   5/27/2016 8:53
# 932     0                                   Saint Barthelemy    5/9/2016 7:13
# 960     0                                            Senegal  6/19/2016 23:04
#
#      Clicked on Ad
# 18               1
# 56               1
# 96               1
# 156              1
# 189              1
# 219              1
# 231              1
# 232              1
# 282              1
# 302              1
# 303              1
# 357              1
# 389              1
# 450              1
# 451              1
# 488              1
# 490              1
# 491              1
# 561              1
# 564              1
# 616              1
# 618              1
# 665              1
# 668              1
# 715              1
# 716              1
# 780              1
# 781              1
# 828              1
# 829              1
# 830              1
# 831              1
# 832              1
# 876              1
# 929              1
# 931              1
# 932              1
# 960              1

# %%
data.loc[(data['Age'].isna() == True) & (data['Clicked on Ad'] == 0), 'Age'] = '10s'

# %%
data.loc[(data['Age'].isna() == True) & (data['Clicked on Ad'] == 1), 'Age'] = '50s'

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95  10s     61833.90                256.09
# 1                     80.23  30s     68441.85                193.77
# 2                     69.47  20s     59785.94                236.50
# 3                     74.15  20s     54806.18                245.89
# 4                     68.37  30s     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#          Timestamp  Clicked on Ad
# 0   3/27/2016 0:53              0
# 1    4/4/2016 1:39              0
# 2  3/13/2016 20:35              0
# 3   1/10/2016 2:31              0
# 4    6/3/2016 3:36              0

# %%
data['Age'] = data2['Age']

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95  NaN     61833.90                256.09
# 1                     80.23  30s     68441.85                193.77
# 2                     69.47  20s     59785.94                236.50
# 3                     74.15  20s     54806.18                245.89
# 4                     68.37  30s     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#          Timestamp  Clicked on Ad
# 0   3/27/2016 0:53              0
# 1    4/4/2016 1:39              0
# 2  3/13/2016 20:35              0
# 3   1/10/2016 2:31              0
# 4    6/3/2016 3:36              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   object
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.2+ KB

# %%
data.describe()
# Out:
#        Daily Time Spent on Site   Area Income  Daily Internet Usage  \
# count               1000.000000   1000.000000           1000.000000
# mean                  65.000200  55000.000080            180.000100
# std                   15.853615  13414.634022             43.902339
# min                   32.600000  13996.500000            104.780000
# 25%                   51.360000  47031.802500            138.830000
# 50%                   68.215000  57012.300000            183.130000
# 75%                   78.547500  65470.635000            218.792500
# max                   91.430000  79484.800000            269.960000
#
#               Male  Clicked on Ad
# count  1000.000000     1000.00000
# mean      0.481000        0.50000
# std       0.499889        0.50025
# min       0.000000        0.00000
# 25%       0.000000        0.00000
# 50%       0.000000        0.50000
# 75%       1.000000        1.00000
# max       1.000000        1.00000

# %%
data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
data['Daily Time Spent on Site'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['Area Income'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['Daily Internet Usage'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['Age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
data['Male'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Male'>

# %%
data['Country'].nunique()
# Out:
# 237

# %%
data['Clicked on Ad'].value_counts()
# Out:
# Clicked on Ad
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
sns.distplot(data['Area Income'])
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_14072\3495980226.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Area Income'])
# <Axes: xlabel='Area Income', ylabel='Density'>

# %%
data['City'].nunique()
# Out:
# 969

# %%
data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
X = data.drop(["Ad Topic Line", 'City', 'Country', 'Timestamp', 'Clicked on Ad'], axis=1)
y = data['Clicked on Ad']

# %%
X.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 0                     68.95  10s     61833.90                256.09     0
# 1                     80.23  30s     68441.85                193.77     1
# 2                     69.47  20s     59785.94                236.50     0
# 3                     74.15  20s     54806.18                245.89     1
# 4                     68.37  30s     73889.99                225.58     0

# %%
X = pd.get_dummies(X, drop_first=True)
X
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  Male  \
# 0                       68.95     61833.90                256.09     0
# 1                       80.23     68441.85                193.77     1
# 2                       69.47     59785.94                236.50     0
# 3                       74.15     54806.18                245.89     1
# 4                       68.37     73889.99                225.58     0
# ..                        ...          ...                   ...   ...
# 995                     72.97     71384.57                208.58     1
# 996                     51.30     67782.17                134.42     1
# 997                     51.63     42415.72                120.37     1
# 998                     55.55     41920.79                187.95     0
# 999                     45.01     29875.80                178.35     0
#
#      Age_10s  Age_20s  Age_30s  Age_40s  Age_50s  Age_60s
# 0       True    False    False    False    False    False
# 1      False    False     True    False    False    False
# 2      False     True    False    False    False    False
# 3      False     True    False    False    False    False
# 4      False    False     True    False    False    False
# ..       ...      ...      ...      ...      ...      ...
# 995    False    False     True    False    False    False
# 996    False    False    False     True    False    False
# 997    False    False    False    False     True    False
# 998     True    False    False    False    False    False
# 999    False     True    False    False    False    False
#
# [1000 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_scaled = ss.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled.head()
# Out:
#    Daily Time Spent on Site  Area Income  Daily Internet Usage      Male  \
# 0                  0.249267     0.509691              1.734030 -0.962695
# 1                  0.961132     1.002530              0.313805  1.038750
# 2                  0.282083     0.356949              1.287589 -0.962695
# 3                  0.577432    -0.014456              1.501580  1.038750
# 4                  0.212664     1.408868              1.038731 -0.962695
#
#     Age_10s   Age_20s   Age_30s   Age_40s   Age_50s   Age_60s
# 0  4.269750 -0.568112 -0.740262 -0.531085 -0.377964 -0.070888
# 1 -0.234206 -0.568112  1.350873 -0.531085 -0.377964 -0.070888
# 2 -0.234206  1.760216 -0.740262 -0.531085 -0.377964 -0.070888
# 3 -0.234206  1.760216 -0.740262 -0.531085 -0.377964 -0.070888
# 4 -0.234206 -0.568112  1.350873 -0.531085 -0.377964 -0.070888

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state= 7)

# %% [markdown]
# # 나이브베이즈 예측 및 평가

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, CategoricalNB
from sklearn.metrics import accuracy_score, classification_report

# %%
nbc = GaussianNB()
nbc.fit(X_train, y_train)
pred = nbc.predict(X_test)
print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.86
#               precision    recall  f1-score   support
#
#            0       0.78      0.99      0.87        97
#            1       0.99      0.74      0.84       103
#
#     accuracy                           0.86       200
#    macro avg       0.88      0.86      0.86       200
# weighted avg       0.89      0.86      0.86       200

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=3, random_state=7)
dtc.fit(X_train, y_train)
pred = dtc.predict(X_test)
print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.95
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        97
#            1       0.96      0.94      0.95       103
#
#     accuracy                           0.95       200
#    macro avg       0.95      0.95      0.95       200
# weighted avg       0.95      0.95      0.95       200

# %%
rfc = RandomForestClassifier(max_depth=3, n_estimators = 1000, random_state=7)
rfc.fit(X_train, y_train)
pred = rfc.predict(X_test)
print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.97
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        97
#            1       0.97      0.97      0.97       103
#
#     accuracy                           0.97       200
#    macro avg       0.97      0.97      0.97       200
# weighted avg       0.97      0.97      0.97       200

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# 0.96
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        97
#            1       0.94      0.98      0.96       103
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
