# %%
import requests

# %%
url ="https://www.beeradvocate.com/community/login/"

# %%
payload = dict(login='아이디' , password='패스워드')
header = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
          'Cookie' : "_pbjs_userid_consent_data=3524755945110770; _cc_id=bf032bf8c5b809af2bdd20fa5049c01b; panoramaId=edbb95ec06c48c32b2fd010ae8be16d5393833b835a8ef6a7981a6b0c721e8c0; panoramaIdType=panoIndiv; panoramaId_expiry=1699945236280; _au_1d=AU1D-0100-001699340437-ELSLTMXQ-LTP1; _gid=GA1.2.2117832649.1699340437; AdvallyAdhesionHide=1; xf_session=9230ead4c106b35190bfe6c497bad6c6; _au_last_seen_pixels=...%3D; __gads=ID=d7113112829a3d01:T=1699340437:RT=1699341935:S=ALNI_MZTKZzpKs-ADdOK7-jdLf0C7eOTkg; __gpi=UID=00000c816cd24a50:T=1699340437:RT=1699341935:S=ALNI_MZWrB9P0c_PHg4AjfP84A40yO_Fsg; _ga=GA1.2.1994879224.1699340435; FCNEC=%5B%5B%22AKsRol9lzCwpCLvpE3nmA5N-j_krWvFxGeB2Dto6-tanXbR3M1r--NTPiCL1rl32hkcz_9210P3hXKhGy5-S8IYAjDS-jGg5biJ65Gjz9nkNRDLJ2NqtBmq4WmgVGQt2XzmjUvQWQFFkDfWzko2e1jvwVzttttS7Lw%3D%3D%22%5D%2Cnull%2C%5B%5D%5D; cto_bundle=eWc2Ol9jb3hiVU00cTJsWHdaVlFYMk0zZ3gwdTRJWjFjTnNBbkFmZHBQTmF4SVFQWjZpQUttZyUyRnhBQ3hucVhtR0IlMkJ5WGNQJTJCb3BjR1JsVW1zVEtkR3dYN3NYWm1JVCUyQmhZeDhHT3pyaWZJRHIlMkZwSUFWMnp6T3ZPYkFzeURQdTZiJTJGdCUyQjRIelpMRm5mV1FuMEE5UzRaSUN0SU9OdyUzRCUzRA; cto_bidid=lw0OlV8zamxhTloxWHBEelFOQkJubHluY3pZTyUyRkZSeG1PMlpVQ2NpJTJGSDFIcFlvQlJIU1A2JTJCQWolMkZObG9uOTdOaURuSTRpUEdlcE95dmNYdzJ0N292YVNRbyUyQjVJNm1FS3NwSUxqV1Z0dEJwOEdndFdNeW1SZkdVRE9OdzBOck9UVXhLR3c; _ga_H9322JE8XJ=GS1.1.1699340435.1.1.1699342027.0.0.0",
          'Accept' : "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
          'Referer' : 'https://www.beeradvocate.com/community/search/1/?searchform=1&q=korea&o=date',
          'Sec-Ch-Ua' : '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"'}

# %%
session = requests.Session()
r = session.post(url, data=payload, headers=header)
print(r.status_code)
# Out:
# 200

# %%
url2 = "https://www.beeradvocate.com/search/?q=korea"
r2 = session.get(url2, timeout=3, data=payload, headers=header)
print(r2.status_code)
print(r2.text)
# Out:
# 200
# <!DOCTYPE html>
# <html id="XenForo" lang="en-US" dir="LTR" class="Public NoJs uix_javascriptNeedsInit LoggedIn Sidebar  Responsive pageIsLtr   not_hasTabLinks  hasSearch   is-sidebarOpen hasRightSidebar is-setWidth navStyle_0 pageStyle_0 hasFlexbox" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <meta charset="utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <base href="https://www.beeradvocate.com/community/" />
# <script>
# 			var _b = document.getElementsByTagName('base')[0], _bH = "https://www.beeradvocate.com/community/";
# 			if (_b && _b.href != _bH) _b.href = _bH;
# 		</script>
# <title>korea | Search | BeerAdvocate</title>
# <noscript><style>.JsOnly, .jsOnly { display: none !important; }</style></noscript>
# <link rel="stylesheet" href="css.php?css=xenforo,form,public&amp;style=6&amp;dir=LTR&amp;d=1696564682" />
# ...
