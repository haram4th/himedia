# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
import numpy as np

# %%
pwd
# Out:
# 'C:\\bigdata'

# %%
data = pd.read_csv("./data/망고플레이트전국댓글.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658251 entries, 0 to 658250
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   리뷰내용    657292 non-null  object
#  1   작성자명    657680 non-null  object
#  2   후기점수    658251 non-null  object
#  3   url     658251 non-null  object
#  4   ID      658251 non-null  object
# dtypes: object(5)
# memory usage: 25.1+ MB

# %%
data.head()
# Out:
#                                                 리뷰내용         작성자명 후기점수  \
# 0                                               맛있네요            -  맛있다
# 1                                               가로수길          전예원  맛있다
# 2                                               맛있어요          전예원  맛있다
# 3  언제와도 맛있는 미라이!!!고등어산도는 무조건 시켜야하구요.. (식빵 뭔지 궁금) ...  스틱스강에맹세하는맛집  맛있다
# 4  아와이 야끼소바,사바산도,우니 아마에비 호다테먹었어요.나마비루도 함께^^나마비루 부...           ㅇㅇ  맛있다
#
#                                                  url            ID
# 0  https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 1  https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 2  https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 3  https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 4  https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO

# %%
data['ID'].nunique()
# Out:
# 5744

# %%
(data.duplicated(['리뷰내용', '작성자명']) == False).sum()
# Out:
# 93320

# %%
data = data.drop_duplicates(['리뷰내용','작성자명'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93320 entries, 0 to 658250
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰내용    93180 non-null  object
#  1   작성자명    93282 non-null  object
#  2   후기점수    93320 non-null  object
#  3   url     93320 non-null  object
#  4   ID      93320 non-null  object
# dtypes: object(5)
# memory usage: 4.3+ MB

# %%
data['ID'].nunique()
# Out:
# 5742

# %%
revire_counts = data.groupby('ID')[['리뷰내용']].count()

# %%
revire_counts
# Out:
#               리뷰내용
# ID
# --IQdCMyShbu     6
# --PbUbWkr5xp     2
# -0aeDar1Ie       8
# -0iuKSUEFRvZ    13
# -1LZImufBV8E     3
# ...            ...
# zwRLQ9Byr2       6
# zxgTXotiK5bQ     1
# zxqKlZqoho       4
# zzs7gkIn9R       9
# zzulPTWCNorK    12
#
# [5742 rows x 1 columns]

# %%
revire_counts.sort_values(by='리뷰내용', ascending=False)
# Out:
#               리뷰내용
# ID
# s6C_cdBQX0rj   372
# 1pmv75vVQx     287
# fPi6OZ3r-u     246
# y-_XMRSTNrAi   241
# gL8RksQTNk     239
# ...            ...
# nwykgqfbYx       1
# AzIdNOqU_tl3     1
# noi8A_NGrRBL     1
# B8sD6M3ts3Aa     1
# VeXkWWPE1HIJ     1
#
# [5742 rows x 1 columns]

# %%
over20revies = revire_counts[revire_counts['리뷰내용'] > 20]

# %%
over20revies
# Out:
#               리뷰내용
# ID
# -1rMxmPWvg      32
# -1yzcgbtF5      96
# -9jLnAAJZc      25
# -D6qxV9cg9mT    23
# -EDDtVfafvaS    29
# ...            ...
# zYzhPaX003      69
# z_sD7nAsh7V0    51
# zq9bIKh6PMLV    37
# ztTTr81jaBm7    98
# zv1rcsrmRU4S    35
#
# [1117 rows x 1 columns]

# %%
print(type(over20revies))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
over20revies_shops = over20revies.index

# %%
over20revies_shops
# Out:
# Index(['-1rMxmPWvg', '-1yzcgbtF5', '-9jLnAAJZc', '-D6qxV9cg9mT',
#        '-EDDtVfafvaS', '-G-YWwpe9D', '-LWflJV1maU2', '-SMNjUsH3i',
#        '-SvQDki5HNzQ', '-UUbd93wKH0H',
#        ...
#        'zNVXE1__XF', 'zOOlz9vfJfFF', 'zSujg5KWKY1W', 'zSxicuDvNH',
#        'zWVgSFqWIQrj', 'zYzhPaX003', 'z_sD7nAsh7V0', 'zq9bIKh6PMLV',
#        'ztTTr81jaBm7', 'zv1rcsrmRU4S'],
#       dtype='object', name='ID', length=1117)

# %% [markdown]
# 전체 데이터에서 over20revies_shops 에 해당하는 가게만 필터링 해서 새로운 데이터 프레임 만들기

# %%
over20df = data[data['ID'].apply(lambda x: x in over20revies_shops)]

# %%
over20df
# Out:
#                                                      리뷰내용         작성자명 후기점수  \
# 0                                                    맛있네요            -  맛있다
# 1                                                    가로수길          전예원  맛있다
# 2                                                    맛있어요          전예원  맛있다
# 3       언제와도 맛있는 미라이!!!고등어산도는 무조건 시켜야하구요.. (식빵 뭔지 궁금) ...  스틱스강에맹세하는맛집  맛있다
# 4       아와이 야끼소바,사바산도,우니 아마에비 호다테먹었어요.나마비루도 함께^^나마비루 부...           ㅇㅇ  맛있다
# ...                                                   ...          ...  ...
# 657692  나름 맛있고 반찬도 잘나오는 편. 수요미식회에 나왔다는데 그정도로 맛집이라기보다는 ...           쵸미  맛있다
# 657693  바싹불고기에 불맛이 제대로 배어있다.육회는 참기름과 마늘향이 강해 고기맛을 느낄수없...           리핑  괜찮다
# 657694  연탄불고기느낌? ㅋ 서울이랑비슷 더 바싹해지면 좋았을듯.. 만팔천원 식사포함.. 덜 달다         무나&뎅  괜찮다
# 657695  언양에 손님이 왔으면 한번쯤 들르는 언양불고기집. 식당의 규모와 구조를 보면 오래되...   Gastronomy  괜찮다
# 657696  This is a bulgogi restaurant in an big old hou...         john  맛있다
#
#                                                       url            ID
# 0       https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 1       https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 2       https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 3       https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# 4       https://www.mangoplate.com/restaurants/iMRRP69...  iMRRP69qtkeO
# ...                                                   ...           ...
# 657692  https://www.mangoplate.com/restaurants/1rKcioby5B    1rKcioby5B
# 657693  https://www.mangoplate.com/restaurants/1rKcioby5B    1rKcioby5B
# 657694  https://www.mangoplate.com/restaurants/1rKcioby5B    1rKcioby5B
# 657695  https://www.mangoplate.com/restaurants/1rKcioby5B    1rKcioby5B
# 657696  https://www.mangoplate.com/restaurants/1rKcioby5B    1rKcioby5B
#
# [60673 rows x 5 columns]

# %% [markdown]
# 리뷰내용 길이가 4 이상인 리뷰만 남김

# %%
over20df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60673 entries, 0 to 657696
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰내용    60559 non-null  object
#  1   작성자명    60644 non-null  object
#  2   후기점수    60673 non-null  object
#  3   url     60673 non-null  object
#  4   ID      60673 non-null  object
# dtypes: object(5)
# memory usage: 2.8+ MB

# %%
over20df['리뷰내용'].isna().sum()
# Out:
# 114

# %%
over20df[over20df['리뷰내용'].isna() == True]
# Out:
#        리뷰내용                작성자명 후기점수  \
# 5625    NaN                 미동이  맛있다
# 13851   NaN  Kelsey Jihyun Park  맛있다
# 26293   NaN                 김지효  괜찮다
# 26295   NaN             Chelsea  맛있다
# 44526   NaN                 또바기  맛있다
# ...     ...                 ...  ...
# 615211  NaN                 김건우  맛있다
# 622034  NaN                 강우형  맛있다
# 634293  NaN               Alice  괜찮다
# 642536  NaN                  쿤스  맛있다
# 652509  NaN           kimchorok  괜찮다
#
#                                                       url            ID
# 5625    https://www.mangoplate.com/restaurants/g-ZF2ky...  g-ZF2ky7D3m-
# 13851   https://www.mangoplate.com/restaurants/8EGPzufM3i    8EGPzufM3i
# 26293   https://www.mangoplate.com/restaurants/aeO_cG35KO    aeO_cG35KO
# 26295   https://www.mangoplate.com/restaurants/aeO_cG35KO    aeO_cG35KO
# 44526   https://www.mangoplate.com/restaurants/s6C_cdB...  s6C_cdBQX0rj
# ...                                                   ...           ...
# 615211  https://www.mangoplate.com/restaurants/UnxQbEABM4    UnxQbEABM4
# 622034  https://www.mangoplate.com/restaurants/-SMNjUsH3i    -SMNjUsH3i
# 634293  https://www.mangoplate.com/restaurants/iSH-kv4Shm    iSH-kv4Shm
# 642536  https://www.mangoplate.com/restaurants/PHhjurE...  PHhjurEApSpz
# 652509  https://www.mangoplate.com/restaurants/nifJY9fGmL    nifJY9fGmL
#
# [114 rows x 5 columns]

# %%
over20df['리뷰내용'] = over20df['리뷰내용'].astype('str')
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4340\3256979473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over20df['리뷰내용'] = over20df['리뷰내용'].astype('str')

# %%
over20df[over20df['리뷰내용'] == 'nan']
# Out:
#        리뷰내용                작성자명 후기점수  \
# 5625    nan                 미동이  맛있다
# 13851   nan  Kelsey Jihyun Park  맛있다
# 26293   nan                 김지효  괜찮다
# 26295   nan             Chelsea  맛있다
# 44526   nan                 또바기  맛있다
# ...     ...                 ...  ...
# 615211  nan                 김건우  맛있다
# 622034  nan                 강우형  맛있다
# 634293  nan               Alice  괜찮다
# 642536  nan                  쿤스  맛있다
# 652509  nan           kimchorok  괜찮다
#
#                                                       url            ID
# 5625    https://www.mangoplate.com/restaurants/g-ZF2ky...  g-ZF2ky7D3m-
# 13851   https://www.mangoplate.com/restaurants/8EGPzufM3i    8EGPzufM3i
# 26293   https://www.mangoplate.com/restaurants/aeO_cG35KO    aeO_cG35KO
# 26295   https://www.mangoplate.com/restaurants/aeO_cG35KO    aeO_cG35KO
# 44526   https://www.mangoplate.com/restaurants/s6C_cdB...  s6C_cdBQX0rj
# ...                                                   ...           ...
# 615211  https://www.mangoplate.com/restaurants/UnxQbEABM4    UnxQbEABM4
# 622034  https://www.mangoplate.com/restaurants/-SMNjUsH3i    -SMNjUsH3i
# 634293  https://www.mangoplate.com/restaurants/iSH-kv4Shm    iSH-kv4Shm
# 642536  https://www.mangoplate.com/restaurants/PHhjurE...  PHhjurEApSpz
# 652509  https://www.mangoplate.com/restaurants/nifJY9fGmL    nifJY9fGmL
#
# [114 rows x 5 columns]

# %%
over20df.loc[5625,:]
# Out:
# 리뷰내용                                                  nan
# 작성자명                                                  미동이
# 후기점수                                                  맛있다
# url     https://www.mangoplate.com/restaurants/g-ZF2ky...
# ID                                           g-ZF2ky7D3m-
# Name: 5625, dtype: object

# %%
# 리뷰내용 길이가 4 이상인 데이터만 저장
over20df = over20df[over20df['리뷰내용'].apply(len) >= 4]

# %%
over20df['ID'].nunique()
# Out:
# 1117

# %%
over20df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60093 entries, 0 to 657696
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰내용    60093 non-null  object
#  1   작성자명    60064 non-null  object
#  2   후기점수    60093 non-null  object
#  3   url     60093 non-null  object
#  4   ID      60093 non-null  object
# dtypes: object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# ID별로 변수를 생성하고 ID별 데이터 프레임 생성
# * globals()를 이용해 자동으로 변수 만들기
# * globals()['변수명']

# %%
# 변수를 만들때는 문자열 포멧팅으로 만들 수 없음
# for index, name in enumerate(over20revies_shops):
#     f"test{index}" = data[data['ID'] == name]

# %%
over20df['ID'] = over20df['ID'].str.replace("-", "_")
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_4340\3928756102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over20df['ID'] = over20df['ID'].str.replace("-", "_")

# %%
ids = list(set(over20df['ID']))

# %%
len(ids)
# Out:
# 1117

# %%
ids[3]

# %% [markdown]
# # 변수 생성규칙
# * 변수는 반드시 문자로 시작해야 한다.
# * 변수에는 -(하이픈)을 사용할 수 없다. _(언더스코어는 가능)

# %%
def dfbyid(ids):
    dfs = []
    for idx, id_name in enumerate(ids):
        globals()[f"d_{id_name}"] =  over20df[over20df['ID']==id_name]   # 변수를 자동으로 생성해서 id별 dataframe만듬
        dfs.append("d_"+id_name) # id가 숫자로 시작하면 변수 생성이 안되므로 앞에 d_를 붙임
        print(f"{idx+1}/{len(ids)} 처리중", end="\r") # 현재 진행 사항 표시
    return dfs

# %%
dfs = dfbyid(ids)
# Out:
# 1117/1117 처리중

# %%
dfs
# Out:
# ['d_ie3TAxVUoaZR',
#  'd_QdnZnky2HnMJ',
#  'd__bfcsv_J9w',
#  'd_zWVgSFqWIQrj',
#  'd__zpN_V3Ogj',
#  'd_3MUdIhk_PbR9',
#  'd_PalvouUA1j',
#  'd_ugW7sOel2u88',
#  'd_UFeL9KXKwjEs',
#  'd_z_sD7nAsh7V0',
#  'd_15HQ3ChMiy',
#  'd_5e4Lb_iMjNo5',
#  'd_aMvqo8Ypz2yP',
#  'd_RYztVEdNVcvZ',
#  'd_P7NK0_5Krz',
#  'd_UQiRamIg89',
#  'd_0fVczJphgFWa',
#  'd_m16fiU1vHZhd',
#  'd_Fy2Z5kqgi_7b',
#  'd_20Wpq5I1IJ',
#  'd_btY7z88DBf',
#  'd_OhE_ArzacE',
#  'd__czYKuW77F_5',
#  'd_mTn8kOvHQc',
#  'd_fwOAsEVZ_F',
#  'd_8HFTOrA16i',
#  'd_mu6tT_DQuq',
#  'd_J7QQDI77g3YC',
#  'd_Gotsc3J4iMFv',
#  'd_J4rryjvWN5',
#  'd_g8HZjdy26NwR',
#  'd_7RxQALnw5C',
#  'd_oJ_sPBI297DQ',
#  'd_1DoTDiGuCe',
#  'd_yNGGQSGw7x',
#  'd_toc6p0Z4J3',
#  'd_5KzJ8jKxwxf7',
#  'd_Jky8JcPbOH',
#  'd_CkAjfohbdKuv',
#  'd__SvQDki5HNzQ',
#  'd_zHeV7AfPBr',
#  'd_lPM5ZHvbKiSI',
#  'd_Ybpa3V5d_aQw',
#  'd_dzvLL3cnX1UC',
#  'd_vnc0i7l_fd',
#  'd_wvZeJsW78zwk',
#  'd_KQI3uO4Kw1wn',
#  'd_l4SRQIFhkEIN',
#  'd_6mrFuZhKejAf',
#  'd_FpcOrX8HT5e2',
#  'd_TV7PVefI8u',
#  'd__SMNjUsH3i',
#  'd_WM78187Gjd',
#  'd_Tp0aaXWTLtt9',
#  'd_AHfFLHT86Lt4',
#  'd_n__6N3tlm_',
#  'd_lmV7_IPVgD3m',
#  'd_0YgK9Ddxpxle',
#  'd_5k7xh0JMDH',
#  'd_wT1_KWIfeZ',
#  'd_1StYTUHMVI',
#  'd_IJxA6CexwFwY',
#  'd_ulZ1u8vYwjgF',
#  'd_zSujg5KWKY1W',
#  'd_Xoqe_P0XzBFZ',
#  'd_vDZvZq79rhP_',
#  'd_00qVg5wrkJzq',
#  'd_2GqhmZhZxO',
#  'd_NyBoPDqM8R',
#  'd_rDxhhQS3Ffn7',
#  'd_tyOwRioS5RlM',
#  'd_AIodGGqVRYId',
#  'd_EQB1ieEn8jac',
#  'd_5HeqtDuK5R',
#  'd_PWY1oxDaBZ',
#  'd_smTe3eQN3z',
#  'd__D6qxV9cg9mT',
#  'd_vGCPzfRZsI',
#  'd_HWp4HhRE_7',
#  'd_qdeaoYsv4a',
#  'd_y5gP4BbLDHA8',
#  'd_MVf7LV9EWM',
#  'd_ug3rOeg_RrKb',
#  'd_nXVbTUBB1x',
#  'd_xS__jmJRTWrW',
#  'd_BJPgSUMkZM',
#  'd_vaSEEQafFwKF',
#  'd_D9eg_mzX_gqZ',
#  'd_5h2OL8a5GlY_',
#  'd_J82M1xz8fF',
#  'd_llrPMa8ZWsCD',
#  'd_Q_g_Tkrf76',
#  'd_9MBV426tZfQc',
#  'd_NyDbhBM5mv',
#  'd_Xu7osGynMN',
#  'd_ElOtkXR8nKHV',
#  'd_cf2E88XyP0y2',
#  'd_cOPpYpvBoWrH',
#  'd_S_nogDkD8F83',
#  'd_V1pDpcDIntci',
#  'd_ewTZ9Le7U54q',
#  'd_CJKTHzGOCQi9',
#  'd_3A0Z_gBcPl',
#  'd_0sdpvAeUeb18',
#  'd_rJ6av3SuzP',
#  'd_L_npHZFJXuDE',
#  'd_by3HdSaaxw',
#  'd_qcFPjfB7o5_X',
#  'd_Uq3uakGOVd',
#  'd_p9qcvd6CIYq5',
#  'd_3ng91j9Q4Y',
#  'd_ztTTr81jaBm7',
#  'd_0thCFqf_UT',
#  'd_BhyH0IOXhv',
#  'd_NjGV4odJU65L',
#  'd_WbGDieg1l8',
#  'd_bev88h8Ck90_',
#  'd__1yzcgbtF5',
#  'd_gL8RksQTNk',
#  'd_E2oMI56ca_bL',
#  'd_PmVAf2YYLp',
#  'd_ttBgrIf02J',
#  'd_IxPgfbX7wag7',
#  'd_C1rSSjpEptN4',
#  'd_5pYPUF2b4YR5',
#  'd_1rKcioby5B',
#  'd_lL4ltwPeWgOO',
#  'd_GvZWLg7ps9w_',
#  'd_PQPyWBW0ymFs',
#  'd_5yc8sn_LpM',
#  'd_T0KqhXajrM',
#  'd_gLlD4v7E13',
#  'd_umDMoedGJg',
#  'd_07mNqSLRxlGB',
#  'd__d9cArzpXEVI',
#  'd_vipX6WCZbJ8z',
#  'd_OhHItizAywPQ',
#  'd_LGXola8pgdAC',
#  'd_d594hYy4NS2H',
#  'd_qQWxtOLljL',
#  'd_GhpMuZQ_lGqh',
#  'd_GWboHAhxKZ8b',
#  'd_MQH6EBR6h8vQ',
#  'd_woOChljkSNyQ',
#  'd_ox9K4mJOWf',
#  'd_N7MPgQHpWe',
#  'd_Tk0mUvsISt3j',
#  'd_qKb6AGwIdr7P',
#  'd_Ml1gM34PUX',
#  'd_B64oLGvWbo5d',
#  'd_QqeR_5G5uWnd',
#  'd_Ll_IdIOuVv',
#  'd_fKzuRlij4D8F',
#  'd_A5NeU_FXeh6z',
#  'd_1_l0js5_m1',
#  'd_9lwUASfsAqk2',
#  'd_opaFM1XeoG',
#  'd_XRoMziImmYCC',
#  'd_Qqn7XnaCEY',
#  'd_jVWVR4ScMaHt',
#  'd_b8_YOCj_Qm',
#  'd_xPBKK3JjW7BC',
#  'd_in8ezN7IbJ',
#  'd__lwTLhPuzfky',
#  'd_GbSbMhOuOn',
#  'd_G1edRf6le6',
#  'd_kO5Rdlm4td',
#  'd_iSH_kv4Shm',
#  'd_Bcbw_lMGoz',
#  'd_Ae8ggD4u0V',
#  'd_0XV1ftp1ee_M',
#  'd_9VLsn_7CfpNv',
#  'd_nGRhjRcz1i',
#  'd_9QYtuVl_82of',
#  'd_e7WmbTezA_',
#  'd_QxTRZZv3Dl',
#  'd_JJe1oXUf6s',
#  'd_uuAlidxvnQ',
#  'd_bCF4FCZPy1Cs',
#  'd_NhZm791BDVzZ',
#  'd_myslZBeMRB',
#  'd_2e_BuFC1TAEo',
#  'd_6bp9NtVjCCwL',
#  'd_HyyQTyz7Dj42',
#  'd_51t4XhhxEGpT',
#  'd_LtQEW4w1BZMm',
#  'd_xLGs_ZuMasCv',
#  'd_EEKW3Lamuv',
#  'd_7XFS4w7F7_',
#  'd_9Gi6030AUV',
#  'd_aOS6mLNLbM',
#  'd_vRjc_JKA_oDW',
#  'd_2Em3ao_AFq',
#  'd_CyyTJOMQ8DrB',
#  'd_W9HA8CD1HJe7',
#  'd_f2yM7Ac3f__8',
#  'd_Xc_dpHjsXu',
#  'd_Hrii5HjHIRoi',
#  'd_gmyDL4cBh9',
#  'd_y_6f0TYITVa8',
#  'd_Rd7B_Vjs_2fU',
#  'd_ZpyE9jWyOKcp',
#  'd__EDDtVfafvaS',
#  'd_s3HTCj99t_',
#  'd_TNywLOfH_r',
#  'd_uiD1qcGYDC06',
#  'd__qloRj_hMz',
#  'd_siQh6pezJ_',
#  'd_dPMQH4nlqZXc',
#  'd_AKBv9lvYHqag',
#  'd_xcgl8hYg4G',
#  'd_OJgUhmMaJOPI',
#  'd_HmKQZLRh7P5u',
#  'd_mcj4cd4eQf',
#  'd_YTeVoK0dx3',
#  'd_XIYzproEJ1',
#  'd_CxTm9IzfC5_x',
#  'd_w_u6_cCr0qX0',
#  'd_lekDtZkiY1Cy',
#  'd_8BR9vSdgpU',
#  'd_6egenVr_V_6_',
#  'd_mseYsQL8gXuC',
#  'd_Hnt91DobCS',
#  'd_zq9bIKh6PMLV',
#  'd_4JnMAbfyYq8b',
#  'd_T_pB9wzaK6',
#  'd_KV9lSGa6xNQp',
#  'd_I0au3ymw_A7q',
#  'd_uEWpasDGgu6t',
#  'd_D9qlNHQs0yta',
#  'd_0mXVkmTdJ7_A',
#  'd_npW57UkUZN',
#  'd_AUBFvfRpvC4J',
#  'd_rkeqOJm82mJ8',
#  'd_V3l_KPwyJC',
#  'd_L8iDeZ30iGIA',
#  'd_h42OwgXlrV',
#  'd_n9ZwosnPSP',
#  'd_2LahfyORsW',
#  'd_2L8yQMWy1Eye',
#  'd_49eM3AzvJg0R',
#  'd_kbkgnjK4Xu',
#  'd_wb8qseDzWz__',
#  'd_K6s5_YGoS8sH',
#  'd_8xdejrQZRz',
#  'd_0Ml4Wl9ZTv',
#  'd_gGMGj5j3cXr2',
#  'd_KCcUzsJWALdw',
#  'd_SaCJTvz6fPV8',
#  'd_03I0OB3Bpg8M',
#  'd_SOtX1qn8lr2z',
#  'd_N4x8dwjiLxdS',
#  'd_JZM6HCHhwWoN',
#  'd_7J_wRiChYddl',
#  'd_ADHrrrBED_',
#  'd_bpGgQ5lPat',
#  'd_KInT11d0ua',
#  'd_mKFXciRtQc',
#  'd_1EQ02fd9oo',
#  'd_JeVeezu0PzIK',
#  'd_d8vvRfSHZk_B',
#  'd_kkTSEK1nWp',
#  'd_yMoUzcjge9Xh',
#  'd_NKeKBl9J2p',
#  'd_X4S8Amh83v3j',
#  'd_cslpSVwOqy',
#  'd_mfwd78vEtS',
#  'd_vAwCxHClYyxP',
#  'd_c2Y7nyFdix',
#  'd_KWYvFbCbtE',
#  'd_1LDBYlR7ZW',
#  'd_B6cFwd_mm2',
#  'd_2VOilscH0DfF',
#  'd_2qFEx0pXrDdZ',
#  'd_k0P7MWiXf6bz',
#  'd_8CC6FTK_x6',
#  'd_qDEx6OvquvRg',
#  'd_JOHRo9QUDRdi',
#  'd_MjWvPGFF6Jp6',
#  'd_BBKgCvGOrJ_K',
#  'd_hvXIIKWqv3V3',
#  'd_eZNFlbAgzP',
#  'd_jvn2aG4heS',
#  'd_tvYBlZ3g8AYI',
#  'd__YlpfJtxXBsm',
#  'd_yQOqaRhFU_UT',
#  'd_V1qxZKSRs1f4',
#  'd_lIjhQ75oiHX0',
#  'd_SMN9i0AWE7sF',
#  'd_4TBJd9gjGDjI',
#  'd__47PQHcxiP',
#  'd_U0VgpPrSIDPw',
#  'd_Nq90QweeDgfW',
#  'd_RuhAIld9MRhW',
#  'd_R1Nzfed1UHqa',
#  'd_lBwwvWFhnPMp',
#  'd_prl1JPZOWqag',
#  'd_nOYRaMrOLDze',
#  'd_kZUywyY8DPyx',
#  'd_JVt0MOgo6g',
#  'd_F4LMucA69A',
#  'd_2J0axpUplhy7',
#  'd_H7qgftiPmv',
#  'd_LiZZB04VmzFP',
#  'd_9fGgkvUgxq',
#  'd_WvYz0dZzXyX7',
#  'd_Do_pQUBxN9_l',
#  'd_p0wRvl72l2',
#  'd_sSnnhR_dDdqz',
#  'd_w8CtNzB9iuku',
#  'd_dQFSBbkQXG',
#  'd_y9jrekAzi1kE',
#  'd_Y5MLo2_mLa',
#  'd_quiOCe8agT',
#  'd_LMC_eb29aE68',
#  'd_iMRRP69qtkeO',
#  'd_bPXcOQnslL',
#  'd_FsBMnKG8dBZs',
#  'd_Qyv_4hcWyNFo',
#  'd_kFP_1Ou79QlN',
#  'd_pI112Z4JVmBn',
#  'd_UrDib5ztR2',
#  'd_eQEXwnrT4cpI',
#  'd_27_EgOQasf',
#  'd_gdRPUuA_2D',
#  'd_Vijff2zllV',
#  'd_toaVKYkuYwR5',
#  'd_L6yxPDbyDGBC',
#  'd_R3iHj7sZaI',
#  'd_lyLIxz2DGg',
#  'd_Enco4KawgR8u',
#  'd_Hr3c9foXkB',
#  'd_SKXF6cbFWcCl',
#  'd_g4_iA6BJ5o',
#  'd_PPQahwaSFrhU',
#  'd_mLqoh6HlyjSd',
#  'd_NlFRruSiC4',
#  'd_QT2Oqp0tHL',
#  'd_naO5C9wSDnbr',
#  'd_IRzTlg4LWoZs',
#  'd_jMyukh_Vkuo3',
#  'd_l0k43OGTH50J',
#  'd_rSo9uQOd8RmJ',
#  'd_jiQPoOdNDqQc',
#  'd_eIt7s1K_xY',
#  'd_HTN8wruMmj',
#  'd_j8C1GHD2xA',
#  'd_gZgArT4cSW',
#  'd_bs2wK46E3R',
#  'd_3JyWTs_O5vx1',
#  'd_LchHcpSY6y',
#  'd_iVAHP06TG_ai',
#  'd_itjLrKjAWN',
#  'd_NjpKcKDN34oD',
#  'd_fPi6OZ3r_u',
#  'd_aPr_R4FpbnHO',
#  'd_kp5sSSoudn',
#  'd_rezMRYMp4eHd',
#  'd_3r3hZ1xTg_',
#  'd_EkiCy9d8fAg8',
#  'd_chRlP6_axm',
#  'd_56aWuL_8Hb',
#  'd_fiY9_x63U8',
#  'd_EjJKJwLcW0',
#  'd_FFEi7Xv1EVal',
#  'd_0qMeHTQX_2Jz',
#  'd__av3GBtK2sPM',
#  'd_Ct7GYnLL_4z4',
#  'd_zD8hOC0DZxT9',
#  'd_adFAd5nyITV0',
#  'd_8c_tpZgCYB',
#  'd_ECgCJHThGX',
#  'd_3jjXa9IhSQ',
#  'd_6efnZA3HqiBe',
#  'd_1pmv75vVQx',
#  'd_gPhzIflAqb',
#  'd_W7ie2Qm0gZ',
#  'd_Eu4M_LuotC93',
#  'd_jqT1UKtOBv',
#  'd_PUhlqAGFRpBY',
#  'd_jsiqKc29By',
#  'd_dKX9LuHmBLx0',
#  'd_AK0N803u7s',
#  'd_o8nWULk5F_aa',
#  'd_Wo4qKB7ESw',
#  'd_4hAcTcdILi',
#  'd_58VdLj8nKS',
#  'd_UIp8NwSb6Y',
#  'd_CNYvPfSCrb',
#  'd_DOqnqbIeugJI',
#  'd_kHHKj3majCAO',
#  'd_gxUqUtrD_IAa',
#  'd_TXkjVTA_MXiL',
#  'd_DtNd7lLzTLZU',
#  'd_KVmJjWB_8d',
#  'd_JjS1bklwYEM6',
#  'd_MuP_lze1DtYJ',
#  'd_kduafZiXUT',
#  'd_8jCN4eIJc9',
#  'd__BTFPcWr_YCv',
#  'd_YKkbu955qj',
#  'd_WQCpdr0DC2',
#  'd_M0WprAlTn6',
#  'd_ENLKrzKHBHlI',
#  'd_62pZKPDZGlHj',
#  'd_3MCwo15GMV4g',
#  'd_w6mLgLXIIaQ_',
#  'd_EM3OjgmlUj4A',
#  'd_PCe52l5p1B',
#  'd_OejLcG2Pku',
#  'd_ixS6hZPONYI_',
#  'd_TKb98SN3qdOr',
#  'd_1B8ARZ_X2Wur',
#  'd_q20qRCRIIS',
#  'd_IG6UzFoo4Y',
#  'd_7RhdvmOMO1',
#  'd_BzvUd3QUxApO',
#  'd_e8ufbUhFzi',
#  'd_UnxQbEABM4',
#  'd__vXifqRyzj',
#  'd_8bMnQH_r40am',
#  'd_QPKEOPHiXM',
#  'd_3hBVUKv8fj2M',
#  'd_9TgE3uc7XPc6',
#  'd_Co_h796vv0',
#  'd_RLf_7Qchkwdk',
#  'd_NlrcpMeHFOzg',
#  'd_K1lhL2EtJRt8',
#  'd_a0QCZ9DPpCq5',
#  'd_KOz4I3BsY8',
#  'd_GUTO5UaLbV',
#  'd_EbDGFQZGBx',
#  'd_AGOTPvf9qd',
#  'd_JlEOAtsbIt',
#  'd_phK__CKmeq_X',
#  'd_qs2kK_LDx0fU',
#  'd_PAVVg2WfDd9d',
#  'd_asbzWXaJjd',
#  'd_p__77S1Qjm',
#  'd__tjn7yYAEu7u',
#  'd_nXfv3Oh_Bc',
#  'd_bFIGUpV1xrg0',
#  'd_LRlpXa9z4A6z',
#  'd_dmj8UoB2lJ',
#  'd_0bz5Ual1g5XQ',
#  'd_Xg0LDOaBhaPX',
#  'd_YtI0ysL08J',
#  'd_bqLPCzn_Zo',
#  'd_hqycWFVzRZ5J',
#  'd_UjiK7BUxljkP',
#  'd_GUxGz2jpufHv',
#  'd_ee_U_VV1Ul3w',
#  'd_3RT5ty2NgR5g',
#  'd_tlWPASuCsTNS',
#  'd_X7jzMeD3uT',
#  'd_l3pZmVnfkR',
#  'd_N4UbwuYRK8J6',
#  'd_UUI1cGLPTeBV',
#  'd_bHVJz_hK9s',
#  'd_r7ZQMAxSau',
#  'd_nifJY9fGmL',
#  'd_aeO_cG35KO',
#  'd_GRaSMNntLR7N',
#  'd_zOOlz9vfJfFF',
#  'd__3QOogUbde',
#  'd_dTIIHvjzYsBA',
#  'd_UIwMHXOYSD',
#  'd_lnFwg6uNv6WO',
#  'd_1fpb_Jz8cp',
#  'd_5GKspyCnVLa0',
#  'd_GUS6ahhpwiMp',
#  'd_b7EeHUXUn7rz',
#  'd_GaVuDvRYzKXt',
#  'd_3lFMnJyFaAfV',
#  'd_e69Pg_sZu1',
#  'd_me7jYDRgXQ',
#  'd_OZ96hk5F1K',
#  'd__UUbd93wKH0H',
#  'd_RBC04pawcXEq',
#  'd_lTMiXudtCvb4',
#  'd_178EfLzI6isu',
#  'd_7fF72nGT3R',
#  'd_q_ImZ_DGRhlY',
#  'd_IO9dLs7lCwL6',
#  'd_QykyLMvPsg',
#  'd_MKr2Uab8Xf',
#  'd_W5pIYirB4Q',
#  'd_fdNmHldme6jk',
#  'd_S8jFDbhGKykh',
#  'd_OduXGf6bwj',
#  'd_RQ7c48ItyS',
#  'd_yPX3jhN3RupT',
#  'd_CE7_Hxv_Ci',
#  'd_kw7egvKQBC',
#  'd_9hj3_IOmjYgy',
#  'd_RxFRdDnCfIGs',
#  'd_OJui0Tcsdd29',
#  'd_Cj_Eq1Z7bp',
#  'd_Ru3a_egfnE5L',
#  'd_LaDksAG6qj',
#  'd_h5mBqhGji_5P',
#  'd_FIxoQZOz_01C',
#  'd_hS3obgro_5',
#  'd_79x8B54zF3',
#  'd_joXmYQa1O6Rq',
#  'd_ZhqlvUkWE6',
#  'd_Zy_2CLAcdp',
#  'd_6uX7yyYce__1',
#  'd_SqI7JhOCrH9A',
#  'd_dbZtB1usggE2',
#  'd_n7UTzGp2eTu8',
#  'd_zSxicuDvNH',
#  'd_bh_j4o8RD5b7',
#  'd_8vq9q9pAMs_L',
#  'd_TiUni946ZA8c',
#  'd_IMSca3mwKRMp',
#  'd_LYBL7h4P6lG4',
#  'd_L6LQdsD4NSLy',
#  'd_r4Stb8LkCPKR',
#  'd_9pIv7vDY70k1',
#  'd_uUHoZ6D0slBh',
#  'd_ALaV_Vd_FXjL',
#  'd_BK53Qu73ke',
#  'd_Jpan4MocWZP2',
#  'd_WX9nij4_rf',
#  'd_9WduVohnusUp',
#  'd_3r46u3gVbD',
#  'd_Hps9zhInl69_',
#  'd_SyqlfkKhlAD0',
#  'd_WftWOAAPd_',
#  'd_ogLsfHRX4bR1',
#  'd_jVvOjkyBPZ',
#  'd_PDZ8dBA3Qa',
#  'd_K9X9Uwxw__',
#  'd_GsNUSk8aMy',
#  'd_J9rv6AzARUUo',
#  'd_6EPYh4jExJUm',
#  'd_iajeeTwC_J',
#  'd__csjvM0O5SlH',
#  'd_32neSWX6F_',
#  'd_bkQLdPEpxU',
#  'd_PHhjurEApSpz',
#  'd_LkuUboV73Gpp',
#  'd_ZRB_LYZ2sBWV',
#  'd_WwryVYxyp6XI',
#  'd_Xkh9GjMYTvHw',
#  'd_s6C_cdBQX0rj',
#  'd_FgInvWD46Z',
#  'd_2RWHSvPm2Rpz',
#  'd_NPbdF_Xc58N8',
#  'd__LWflJV1maU2',
#  'd_ZojRTpdwjWDf',
#  'd_GK1HUEuElG',
#  'd_jIt9_XnE50',
#  'd_6dj_d_Cgx0Df',
#  'd_JH3bhstVpYnz',
#  'd_Jkb2G3F6SPry',
#  'd_vZ74ooBDahfg',
#  'd_RvHmM2b0ly',
#  'd_Yf4ZnjI3zUw8',
#  'd_4Kg1JS_Vboqo',
#  'd_lB8lmAXFGc',
#  'd_VbCsf9Soqz',
#  'd_uNynTVBxuBBK',
#  'd_4yFJkIDXrQ',
#  'd_jir8uDJCA14B',
#  'd_iXYb9zh8_j',
#  'd_yhLPJnTWt17m',
#  'd_1yKTH5IUp_bE',
#  'd_uFqIRgoPhzZt',
#  'd_L29qKbKIPn2Z',
#  'd_eosoch5KLZ',
#  'd_621n6YuuucvO',
#  'd_4qnCi8_87ger',
#  'd_R4zYqZhSy1',
#  'd_melVoIUI8x',
#  'd_e7LCOR4AEI',
#  'd_S5y9lf5rmnc4',
#  'd_vI2c9_tWVwoc',
#  'd_Qaswimx_AR',
#  'd_VfRDV23Aid',
#  'd_9ZbDjGY8ohoJ',
#  'd_OLEZi7OPhV',
#  'd_PRp5uBgsOXUB',
#  'd_Lw6sdQY6Z0ke',
#  'd_2l48BobR4R',
#  'd_jtk1f_ppQYT7',
#  'd_LMOnpDfa9HoA',
#  'd_Ypypx3AOZN',
#  'd_mHUN9NmKbt',
#  'd_FlLnM4E0CUuz',
#  'd_2u_4_3abGwI4',
#  'd_oumeyZ9XSyIS',
#  'd_2wtiscsaQaS0',
#  'd_eumy5vRx5i',
#  'd_PhBnY0sCs8yd',
#  'd_aU9XYWbj0z',
#  'd_p4hlQ7fhOfyO',
#  'd_Xpj5KZnWSt',
#  'd_PJ6p5FQrRI',
#  'd_lqcBo6HquL',
#  'd_w_Uk02YqcI9h',
#  'd_UN15dCZIP3Cw',
#  'd_SapvvirrPYwo',
#  'd_drXX2BDsGZ',
#  'd_H6EKPX1ASO',
#  'd_0lx8pTEifa',
#  'd_VRGicl0oDQ5O',
#  'd_BJk2Z6emjA',
#  'd_gTeEJOTziy1W',
#  'd_r5ZoupYsk_',
#  'd_7RC_kR4A9C9O',
#  'd_KfI__Cp0EmSD',
#  'd_p8RAHMrhZK',
#  'd_DKzrMaulXR',
#  'd_mjR_ZoQd1e',
#  'd_5SiFoyakrq',
#  'd_aE9sGHedGUlj',
#  'd_8Bfjdp4OgkUX',
#  'd_MIGi8MXfr_',
#  'd_u7hE5GfhEz',
#  'd_SDE1sBTY79Wu',
#  'd_dlG6_fId6D2Y',
#  'd_GQPE6BUVsT_E',
#  'd__QTQ8AeF2j',
#  'd_8TEVbLAud8hP',
#  'd_n0XRmig_pp',
#  'd_zv1rcsrmRU4S',
#  'd_R_LCV_3CKck4',
#  'd_XFe6Dh0ixpl9',
#  'd_StJxVqjld9',
#  'd_ymYUTOZ68_cH',
#  'd_84DJ8U47GUfq',
#  'd_qEAju8hXQs',
#  'd_6CZwyyCzr6qI',
#  'd_CbdJqQErxKsX',
#  'd_WgNmxFtjLx',
#  'd_IP_JKNwjYkyz',
#  'd_Entd6J5XYyQ8',
#  'd_TntIkjwpCV40',
#  'd__TozWY_tTv',
#  'd_JMPdsHevf_',
#  'd_MyeCz_JlSgan',
#  'd_YqO915KDI9',
#  'd_iYXmuzgMI1uc',
#  'd_483ztkTDLrJX',
#  'd_N6w7uRM87AFF',
#  'd_KJo3zG_phR',
#  'd_mx0_4tn_N5Oe',
#  'd_PmeqDEWbEU',
#  'd_L_cDAgLntn',
#  'd__9jLnAAJZc',
#  'd_w9GYYZiAKS',
#  'd_1rG7JRuERfSC',
#  'd_iLgR6ap_84xv',
#  'd_XensLeCfhL',
#  'd__7MTHsDE7UXc',
#  'd_8EGPzufM3i',
#  'd_mIomHshZmH',
#  'd_gb89RnF85m',
#  'd_KTpJnBIAAiWK',
#  'd_oEziZzPmJ6',
#  'd_qgBG3kgmuo',
#  'd_dnN_dL1XdP',
#  'd_Op6Tv2NICk',
#  'd_2gwPM1zoAmDm',
#  'd_6FYtdjIgIr',
#  'd_G4xCyd9vaB',
#  'd_R8oaGDYmjCXQ',
#  'd_NXioT2lvlIi9',
#  'd_0hflR8ZCg5',
#  'd_G07mDodq0doD',
#  'd_2_sFMbsZC9HC',
#  'd_CU4KmdWT6g',
#  'd_cTAy9QS_J5cl',
#  'd_Xj2HvKVOJy',
#  'd_dpvakhAcHJ',
#  'd_ineF3MIAormc',
#  'd_6jn62SUIF6',
#  'd_q1PDtSFDsXea',
#  'd_3LTRib0nn9cN',
#  'd_TvK3uuPDZ9',
#  'd_6xQY0t3A6o',
#  'd_DG9WuFwF8U',
#  'd_QipTpfE2QC',
#  'd_XaSTBeV5Eu',
#  'd_ULxmbNiSxZ',
#  'd_p_1rAzvY7V',
#  'd_Y4DpD3wFYBeb',
#  'd_K0lxqJlzqo2J',
#  'd_At5HxAIOYwzS',
#  'd_3QUGIFzva0',
#  'd_ol9BImtmnFqo',
#  'd_9rXplW6ajjWI',
#  'd_rUwZtDZck8',
#  'd_lrhqu5J2Kg',
#  'd_yYhe7xVxXx',
#  'd_2NG2Ehby9t',
#  'd_qT81KJGY_xXy',
#  'd_ugq5zpw24LjX',
#  'd_FMiCE19Sbgm8',
#  'd__xVh_QZrOMo3',
#  'd_QsBxSFbx6G',
#  'd_c_etEDzpu97_',
#  'd_u_AQIikZZn6t',
#  'd_oArmwzCBGZ',
#  'd_02sGwSC9_K_E',
#  'd_BOYPLw_sEbew',
#  'd_MMokYreq5Q',
#  'd_sFf4Cwoj_h',
#  'd_Yvk9prtD5n9U',
#  'd_shpyryy_x4',
#  'd_QbgCtqqKU0fE',
#  'd_ZiIldxQxUr',
#  'd_bcVFyFD5SL',
#  'd_LkytIui3Xg',
#  'd_B9NGvy4_yJ',
#  'd_LVixjKB0N9TZ',
#  'd_l45tGeIE_JPk',
#  'd_Kh_IH9JfL_',
#  'd_4_daAHUP0LMt',
#  'd_BL932_FjUezw',
#  'd_rRTpq9taxWOj',
#  'd_WoG3dFGCjtnA',
#  'd_cLl3wantj6in',
#  'd_HN1U16KgCI24',
#  'd_lSKKCRS2RJ',
#  'd_c6Wpmzll_0sN',
#  'd_Q9buIpfxMG9X',
#  'd_lNGf0ef7vT',
#  'd_BJrwHJQ2_3ua',
#  'd_EKqwrA1KDZ5c',
#  'd_HgoYULEWz_SX',
#  'd_RTC_u7jrxHMl',
#  'd_yu7aBkM2ylbM',
#  'd_P3jgmS_Fnw',
#  'd_EsviUzRx9v',
#  'd_HyUpZ6sVEo',
#  'd_go9COSz7hx',
#  'd_8HbnV3k0rX',
#  'd_8Osj2Mm_57Ux',
#  'd_EbvI3yQuB2',
#  'd_YLwo_U_ecQ',
#  'd_fGA_KR1YfN',
#  'd_MiUxOS4Sd6',
#  'd_UgFHZZczFUX_',
#  'd_QTFlS_HOiV',
#  'd_uD_vMbGOhW',
#  'd_mfpgS9_h0YYY',
#  'd_9VTI9xu02vXM',
#  'd_PSgsnTisSpxC',
#  'd_piPw4gb_M8',
#  'd_A2WMRSbPSYb_',
#  'd_1PJfkVvvhrig',
#  'd_17eBJOZQgYbL',
#  'd_FeG0lMEO5oMD',
#  'd_m5bgqLtixHIP',
#  'd_u0u27s1DQ9D0',
#  'd_uzUJiTN4NN',
#  'd_K2TXHsay6ieT',
#  'd_V6xxv1kC_g',
#  'd_N7WkeEyqrUiC',
#  'd_hB50_nmo6wNO',
#  'd_b5hozNJvSn',
#  'd_c2MLJKpooZ',
#  'd_n3DOag6F8BPe',
#  'd_39q823jdA1',
#  'd_ROV9aPmsdo',
#  'd_sBb2ypsWeE',
#  'd_ClCOTAkzrB',
#  'd_xeVvmrToKrul',
#  'd_wgLcFMiJ0pEc',
#  'd_9q9iVX7epr',
#  'd_WupMPmXk6_',
#  'd_JWY3qhWuhV',
#  'd_5w3XQVn5Ce',
#  'd_kVU1bi4E1OMj',
#  'd_TovtkS_pCpIg',
#  'd_I_kkCnpK8aV9',
#  'd_6YgOviFI80',
#  'd_l4xy6mRsW0tK',
#  'd_4Zcp4HYDFaS9',
#  'd_8lZn8Qcgj2',
#  'd_z8A3s7Yr8Skr',
#  'd_HQ_73o45zp2m',
#  'd_yryb7HvkPwFP',
#  'd_ssak6AYuxn',
#  'd_78XDv53pER',
#  'd_MlYlQwcNxHL3',
#  'd_lJTpl10oBA',
#  'd_eLq_Q72bscee',
#  'd_XtoUWBHKT6wT',
#  'd_EO8wZBq26I',
#  'd_a4Ux84gbMB',
#  'd_mZC6I_NXse',
#  'd_tVGs0x42pLKv',
#  'd_0FwTUkRDbF',
#  'd_HCVSrS2ETn',
#  'd_B2Xej50_qhqL',
#  'd_HIDvzyb5PI',
#  'd_S2ukxlPLTf_J',
#  'd_8f3EsL0cak',
#  'd_7j8ZGisKSg',
#  'd_RWCP6wA_tH',
#  'd_RzN44_jLTI',
#  'd_sBEJ0nlnODJI',
#  'd_wMwN6Eo0Fn',
#  'd_xNFq8lUiWH',
#  'd_0wz7YU0ZLP',
#  'd_QEv1wVO8L_Dk',
#  'd_Rs06O2sGxMmy',
#  'd_6CL8lm8a_sTa',
#  'd_uzUfRduwc0je',
#  'd_7DQsq__rh_6R',
#  'd_ek0x9JLb5y',
#  'd_jFWl95c1KbXZ',
#  'd_iN20jIV2Vt',
#  'd_7XuIEQ0pkVok',
#  'd_YVbv62Tb1C',
#  'd_6uwqywv4T8',
#  'd_xnnyUhC4HxCF',
#  'd_N257bQ0JtQ',
#  'd_rGU39IqaaEHz',
#  'd_NJPBgqNmB4zo',
#  'd_tIo6g04Z5j',
#  'd_2vnOTM9ggO9_',
#  'd_gHlxXTgqsP',
#  'd_X9RYmjG8D3',
#  'd_pREc02ym4n',
#  'd__lyoPbsT9s97',
#  'd_kMCZauqNZL',
#  'd_mq1ovWy5JEbL',
#  'd_c74WdbCYvI',
#  'd_Bph0RKasAc',
#  'd_k6tCnrg0Z6',
#  'd_9EVyzauilukl',
#  'd_ZGMEfkrGQqQX',
#  'd_2l52up6B6MvY',
#  'd_d0qJSiT8ESUf',
#  'd_XV5xkvKoJFIi',
#  'd_OiGx5gttdCFM',
#  'd_YNrQYS_HUc9n',
#  'd_iV3aTtbQAY',
#  'd_DJjW5pG4aw',
#  'd_TZr70fpRQaOl',
#  'd_tCV5CXuBYX',
#  'd_o3LQKSkc78',
#  'd_49h_AiDK_x',
#  'd_HXHddB8K6dak',
#  'd_Qmjyzoyz2_',
#  'd_fBVd5rEQHN',
#  'd_qiinV6W6sC',
#  'd_95qxQRtNJ7',
#  'd_oVQKeCYTYXT9',
#  'd__bzAPOyu68',
#  'd_KfToFUSQwI',
#  'd_wbnP4WrJWT',
#  'd_Tw3mq1lxwDCh',
#  'd_GqmfRX_lmi8f',
#  'd_iXobcHXQf6',
#  'd_jAyhCGJ_Dn',
#  'd_l7VtxjH0Bo7m',
#  'd_pNK2QW5o6fnj',
#  'd_qF1Qg1uOXN',
#  'd_85X6w7IYsEEj',
#  'd_yf06Mlf96h',
#  'd_IGPyzMELa6',
#  'd_JjqOtUVOBpM9',
#  'd_eoRE9kNPhS',
#  'd_NgsGd9QAvtII',
#  'd_RaVUGWzIA9',
#  'd_xVAE93pPwPHe',
#  'd_huHObYt4jS',
#  'd_HXFqrwoUQ5',
#  'd_L_01tNvT5H_Y',
#  'd_0TkoIX33V9',
#  'd_HpbGe61Wn2T9',
#  'd_2jJkVcqdMz',
#  'd_0ZBL14x1k0Re',
#  'd_TWmgsQJyCZ_6',
#  'd_vkE5tx5MgycG',
#  'd_nEiKR4cowP',
#  'd_Fvgyq1HAiny6',
#  'd_SgKElfslsEvJ',
#  'd_eSfZdpd6PD',
#  'd_gwA_7QSRZAS_',
#  'd_DB_nxyYhQbEJ',
#  'd_1YOKBfjGS7LU',
#  'd_8q085g_q1Pu4',
#  'd_J9i5c2EuAL3w',
#  'd_QXAu6t6L04',
#  'd_P6JpThwq_M5R',
#  'd_u10LmAekc5',
#  'd_Br4jEi_pqzqz',
#  'd_y4pGEk_ZwDqZ',
#  'd_z_4tCw3TKCKn',
#  'd_452dR_5Hxo',
#  'd_xhT_Oi0nDTh3',
#  'd_K3jgqNWezoPJ',
#  'd_ZpE60fZcfqLK',
#  'd_CJOMhPoo0lKK',
#  'd_bKBEWmF8MVGb',
#  'd_gQUKnpHqDvPM',
#  'd_FpbmFFRzdx0r',
#  'd_BiXyFFcayr',
#  'd_LbGNYSGTnVea',
#  'd_Xy2DIpxdFd',
#  'd_XxaofOrFPS7c',
#  'd_gczaSZvc3W5b',
#  'd_Ua8hgaePdWis',
#  'd_jJVFxakTvMh_',
#  'd_zJWBejmpConQ',
#  'd_zNVXE1__XF',
#  'd_hIMp9FCTss',
#  'd_5vEzVX3xJZ1Y',
#  'd__cVwiaiza5',
#  'd_EI2Z304ave3h',
#  'd_kbo6CkIp6d',
#  'd_BKGj7S4wLeUP',
#  'd_xnnLJ68ll1',
#  'd_qJU5J5hrxX',
#  'd_qDmfXQr34Kts',
#  'd_RNdc2ShnTc4A',
#  'd_SdbBGGIUIdRR',
#  'd_RUAaH7p5m8c_',
#  'd_GOcaPhTY0fTg',
#  'd_stm2laE_O_',
#  'd_OaKrC5BEc1',
#  'd_y__XMRSTNrAi',
#  'd_QZoWDJJ1go',
#  'd_WlCN9CJbEBwW',
#  'd_O1QXQFRgYP',
#  'd_0on9_e46dwvb',
#  'd_Bj_3OuGXs5G4',
#  'd_uRyOm_frZKEJ',
#  'd_iqRglQ9mvs89',
#  'd_J3PdFUAW1z6v',
#  'd_hvFSNa2dnc',
#  'd_lKrI9NWcRu',
#  'd_FfhZHT6Cc4Fk',
#  'd_G2ru9jzd7nEu',
#  'd_OPF1Negsc_vb',
#  'd_tBo4Hr5boy',
#  'd_y6zExNVV6NPK',
#  'd_irwgkrmBjL4b',
#  'd_yZ5V83vhJ7jW',
#  'd_NWmtAsUChc',
#  'd_IUzFZelxH_',
#  'd_KWAbqJTAHmb_',
#  'd_I8P8ZFWKNZp3',
#  'd_iXjQqcw9rdi4',
#  'd_1ubJn78JKcyx',
#  'd_PQaNjVqEnjj_',
#  'd_xhAaFxEjCM',
#  'd__G_YWwpe9D',
#  'd_Q3pIhvKw1r',
#  'd_HmA2OLXpsoT_',
#  'd_EzqU3evw9Q',
#  'd_lgxTnsHXRw',
#  'd_3h_3tYBMkeyb',
#  'd_DBLym1DsA0t3',
#  'd_7SS6_guzJWfm',
#  'd_Gv4eevh7WFa6',
#  'd_BOBHdXFfDJtp',
#  'd_e5avGLO5hjJM',
#  'd_0my2hMzHlOYD',
#  'd_xY_ZIKuzPn7c',
#  'd_H5pL71hPrP',
#  'd_kw9JM_fDCE',
#  'd_Dggj0Te0ziYC',
#  'd_GiyIDtkHWg',
#  'd_nJpaHmMi3y',
#  'd_ldYYbW06oG1B',
#  'd_sw8_ZkcgPt',
#  'd_Wo0aRAVV8MGH',
#  'd_RZtDXQuloF38',
#  'd_NWjNoBa23W',
#  'd_Ev9M9HBwCqO9',
#  'd_TFF0OOnb_GBn',
#  'd_dqL32F_fFBqa',
#  'd_K3pW4r43G8',
#  'd_Lz_ubT1nJ_sc',
#  'd_yTdglbq6qbHD',
#  'd_xByAXkflQl8r',
#  'd_71KcF_LODj',
#  'd_GN9VBv4DEGlr',
#  'd_koJ_1vE9dB',
#  'd_qvlVU_HD1E',
#  'd_0sBAZGJAMnJW',
#  'd_ORd_o6IEQz0V',
#  'd_7Oodr8DDRR',
#  'd_NezfTuyKzzEX',
#  'd_wTrefIY2z0kY',
#  'd_6nFjiGvg_XaB',
#  'd_rb3_HpDn7OXJ',
#  'd_Qe4qpFaIVNjY',
#  'd_0eY8YzMwpZ',
#  'd_DgRCxk7eoWVA',
#  'd_3pC7ThiRL4MA',
#  'd_oTMDQ2Djqd9T',
#  ...]

# %% [markdown]
# id별 데이터프레임에서 리뷰내용을 추출해 id별 변수에 합치고, 텍스트 전처리 하고 워드클라우드 만들기

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
for val in globals():
#     print(val)
#     print(type(val))
    if val[:2] == "d_":
#         print(val)
# Out:
#   Cell In[90], line 5
#     #         print(val)
#                         ^
# IndentationError: expected an indented block

# %%
for val in dfs[:2]:
    display(globals()[val])
# Out:
#                                                      리뷰내용         작성자명 후기점수  \
# 165813  #성수 맛집 #뚝섬역 맛집 #서울숲 맛집부산에서 올라온 사촌언니가 서울 최고 맛집을...           숑아  맛있다
# 165814  원픽 화덕피자. 여기 비스마르크는 정말 내가 너무너무 사랑하는 맛이다. 긴말이 필요...         Jake  맛있다
# 165815  Calabrese 28,000 - 토마토소스, 케이퍼, 블랙올리브, 쵸리조, 소프레...          최민규  맛있다
# 165816  서울숲 | 다로베 ***- 다로베피자, 라구파스타이 세상엔 정말 맛있는 피자집이 많...           보리  맛있다
# 165817  다로베 피자 27000 + 부라타 치즈 4500아마트리치나나 28000?네이버 예약...    식비 벌기 빡세다  괜찮다
# ...                                                   ...          ...  ...
# 169704  가게에 손님이 워낙많아 접객도 정신없는 와중에도 피자가 너무 맛있어서 감동했던. 부...         Lenn  맛있다
# 169705  한창 핫한 성수동 다로베! 압구정 살바토레의 오픈 멤버(?)였던 분이 오픈한 곳이라...  Ashley Jung  맛있다
# 169706  Fancy Dan pie in a fancy Dan building on a fan...       Hello!  맛있다
# 169903  Delicious handmade pizza made in a traditional...     Mike Kim  맛있다
# 169904  Tried the appetizer collection, seafood pasta,...           ZN  맛있다
#
#                                                       url            ID
# 165813  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 165814  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 165815  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 165816  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 165817  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# ...                                                   ...           ...
# 169704  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 169705  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 169706  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 169903  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
# 169904  https://www.mangoplate.com/restaurants/ie3TAxV...  ie3TAxVUoaZR
#
# [196 rows x 5 columns]
#                                                      리뷰내용           작성자명 후기점수  \
# 438103  유명하다고 말만 듣던 영동장어...전화로 예약했습니다~주차는 발렛!갯벌장어 4인분 ...    스틱스강에맹세하는맛집  맛있다
# 438104    민물장어 먹었는데 가격도 상권대비 정말 괜찮고 맛도 좋았음와인 콜키지해서 마시기 좋음             WJ  맛있다
# 438105  엄마 생신날 갔음.매번 방문에도 불구하고 장어를 진액이나오는걸 보여주시길래 두번이나...             민정   별로
# 438106  성시경의 먹을텐데에서 보고 방문!!장어 너무너무 통통하고 담백 그 자체..첫점은 소...           thnk  맛있다
# 438107  비린내 없이 담백하게 장어를 먹을 수 있었던 영동장어! 강화갯벌장어(1인분-82,0...           맛집중독  괜찮다
# 438108  장어먹는걸 좋아하는데 장어 종류는 잘 모르는 사람인데.. 친구가 영동장어는 갯벌장어...            스위밍  맛있다
# 438109                      갯벌장어 3인분, 북해도우니와 육회세트까지 모두 굳!            코코팝  맛있다
# 438110  논현동에 위치한 “영동장어”. 성시경님 유투브에서도 소개된 집이지요!! 맛있다고 소...             Jㅐ  맛있다
# 438111  강화갯벌장어구이, 육회와 북해도산 우니!감태에 육회, 우니, 아보카도와 와사비를 올...            코코팝  맛있다
# 438112  어마무지한 장어 비주얼을 보고 찾아간 장어 요리 전문점외관은 최소 30년 된 노포 ...           류흥로그  맛있다
# 438123  소고기집 뜨락과 돼지고기집 금돼지식당이 합심하여 차린 물고기집오픈한지 얼마 안되어 ...             형석  괜찮다
# 438124  깔끔하고 먹을만은 합니다만 저가격에 굳이라는 생각이 들고 몇번이나 불러서 식사 주문...            박성욱   별로
# 438125  내 살면서 적지 않은 장어를 먹어왔지만, 이런 빛깔이 나는 장어는 첨 봤다. 서울에...        Colin B  맛있다
# 438126                                      역시 오늘도 맛있어요!!             솔트  맛있다
# 438127  완전 맛있어요~ 다만 가격이 조금 부담이 됐네요~장어 사진 찍고싶으신 분들은 3인분...           ㄱ최동진  맛있다
# 438143              실한 장어.맛있어서 주변에 소개도 많이 했어요.복분자술은 꼭 드시길             솔트  맛있다
# 438144                     장어가 엄청 크고 맛이 기가 막힘..먹어본 장어중에 탑          느린토깽이  맛있다
# 438145                                비싼값을 하는 엄청난 굵기의 장어들            쓰피겔  맛있다
# 438146  뒤늦은 리뷰.갯벌장어를 주문했더니 직접 요리할 장어를 가져와 보여주심. 생각보다 엄...            NPC  맛있다
# 438147  인생 첫 장어구이! 쫄깃하고 너무 맛있다 가격이 살짝 사악하지만 그거 빼곤 다 완벽...            Lia  맛있다
# 438168                                    비싸서 문제지. 장어 끝판왕  Raon's father  맛있다
# 438169  몸보신을 위해 달려간 논현동 영동장어 다소 가격은 있지만 맛은 보장하는곳 장어는 푸...            케이트  맛있다
# 438170  내가 감히 맛있다 맛없다 평가할 수 없는 미식의 세계는 바로 장어. 느끼한 비릿함과...             정민  맛있다
# 438171                                         아 여긴 꼭 가세요            맛맛맛  맛있다
# 438172  그 유명한 영동장어를 드디어 먹고 왔어요!! 주말에 예약없이 갔다가 그대로 빠꾸를 ...             다다  맛있다
# 438198  논현동에서 장어 맛집으로 급부상 중인 영동장어에 다녀왔어요~장어집스럽지 않은 고풍(...         고독한대식가  맛있다
# 438199  괜챦은곳이다.구성좋고 굽는분도정성을담아 구워주신다.갯벌장어는 식감이적당하면서 먹기좋...             샤이  맛있다
# 438200  장어를 구워주신 분이 너무 능숙하게 잘 하셔서 물어보니 이전에 금돼지식당에서 근무하...             MH  맛있다
# 438201  <리뷰원정대 끝나야 공개하고 싶은 소중한 집 3위> #논현동 #영동장어"평범함을 극...     Luscious.K  맛있다
# 438202  아나콘다인가 장어인가!!! 2명이서 강화도갯벌장어 2인분에 맥주 한병이랑 공기밥 하...         Claire  맛있다
# 438233  #불금 #저녁모임. 멍뭉이들밥주고 저녁에 기어ᄂ...       claire_k  맛있다
# 438234  한줄평: 식어버린 기운도 솟아난다! 금돼지식당+뜨락의 만남으로 주목받는 민물장어 전...             예랑  맛있다
# 438235  오동통한 장어를 맛보기 좋은 곳.논현동에 위치한 장어구이 전문점. 큼지막한 외관에 ...        Wchelin  괜찮다
# 438236  장어는 잘 모르지만, 그래도 열심히 맛있게 먹었다 소문의 갯벌장어는 말 그대로 대단...              림  맛있다
# 438237  19년 마지막 밋업으로 방문한 영동장어소고기의 뜨락과 돼지고기의 금돼지식당이 차린 ...             형석  맛있다
# 438273  애초에 나는 장어 알못이고 평소에 잘 찾아먹지 않는다는 점을 미리.. 알려둔다..!...    Ashley Jung  맛있다
# 438274                  제대로다. 장어같은 장어 드시고 싶으면 여기나 송강을 추천함           chie  맛있다
#
#                                                       url            ID
# 438103  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438104  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438105  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438106  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438107  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438108  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438109  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438110  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438111  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438112  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438123  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438124  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438125  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438126  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438127  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438143  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438144  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438145  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438146  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438147  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438168  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438169  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438170  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438171  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438172  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438198  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438199  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438200  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438201  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438202  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438233  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438234  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438235  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438236  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438237  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438273  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ
# 438274  https://www.mangoplate.com/restaurants/QdnZnky...  QdnZnky2HnMJ

# %%
pwd
# Out:
# 'C:\\bigdata'

# %%
a = "몸보신을 위해 달려간 논현동 영동장어 다소 가격은 있지만 맛은 보장하는곳 장어는 푸..."

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
a.translate(str.maketrans(".", " ", string.punctuation))
# Out:
# '몸보신을 위해 달려간 논현동 영동장어 다소 가격은 있지만 맛은 보장하는곳 장어는 푸'

# %%
def wcByShop(dfs):
    import string
    from emoji import core
    from wordcloud import WordCloud

    font_path = "C:\Windows\Fonts\malgunbd.ttf"
    # 리뷰내용 컬럼의 리뷰를 1개의 변수에 저장하고, 텍스트 클리닝
    for val in dfs:
        test = []
        globals()[val]['리뷰내용'].apply(lambda x: test.append(x))
        test = " ".join(test)
        test = test.translate(str.maketrans(".", " ", string.punctuation)).replace(" ͡°", " ").replace("ㅠ", " ").replace("ㅋ", " ").replace(" ͜ʖ ", " ")
        test = core.replace_emoji(test).replace("ㅎ", " ").strip()

        #  wordcloud 만들기
        wc = WordCloud(
            max_words = 200,
            font_path = font_path,
            background_color = 'white',
            stopwords = []
            ).generate(test)
        plt.figure(figsize=(10,10))
        plt.imshow(wc)
        plt.axis('off')
        plt.savefig(f"./data/wc/{val}.png")
        plt.close()
    print("가게별 워드클라우드 생성 완료")

# %%
wcByShop(dfs)
# Out:
# 가게별 워드클라우드 생성 완료
