# %% [markdown]
# 네이버 웹사이트의 Naver 책 페이지에서 원하는 분야의 키워드로 책을 검색 한 후<br>
# 책 제목, 저자, 출판사, 출간일, 가격, ebook 가격, 소개 글을 수집 및 저정한다.<br>
# 라이브러리는 requests, BeautifulSoup4를 사용한다.

# %% [markdown]
# # 1. requests모듈: HTTP 프로토콜을 사용할 수 있게 해주는 라이브러리
# * requests모듈 사용 설명서 https://requests.readthedocs.io/en/latest/

# %% [markdown]
# # 2. requsts 모듈 설치: conda install requests, pip install requests

# %% [markdown]
# # 3. 모듈 불러오기: import requests

# %%
import requests

# %% [markdown]
# # 4. http 접근 요청 get
# * r=requests.get(url, parameters)

# %% [markdown]
# # 5.  url 파라미터: payload 변수에 딕셔너리 형태로 저장 후 params에 할당
# * r=requests.get(url, params=payload)

# %% [markdown]
# # 6. 만들어진 URL 확인: print(r.url)
# * print(r.url)

# %% [markdown]
# # 7. header 값 넣기: header 변수에 딕셔너리 형태로 저장 후 headers에 할당
# * r=requests.get(url, params=payload, headers=header)

# %% [markdown]
# # 8. 응답요소: text, json
# * r.text: text 형태의 자료 받기
# * r.json: json 형태의 자료 받기

# %% [markdown]
# # 9. 응답코드: .status_code
# * 200: 정상
# * 400: 클라이언트 오류 404 not found
# * 500: 서버오류
# * r.status_code

# %%
url = "https://search.shopping.naver.com/book/search"

# %%
payload = dict(bookTabType='ALL', frm='NVSHSRC', pageIndex=1, pageSize=40, query='파이썬', sort='REL')
payload
# Out:
# {'bookTabType': 'ALL',
#  'frm': 'NVSHSRC',
#  'pageIndex': 1,
#  'pageSize': 40,
#  'query': '파이썬',
#  'sort': 'REL'}

# %%
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
# Out:
# https://search.shopping.naver.com/book/search?bookTabType=ALL&frm=NVSHSRC&pageIndex=1&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# 200

# %%
response = r.text

# %%
response
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta charSet="utf-8"/><meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no"/><title>파이썬 : 네이버 도서</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/img/favicon.ico"/><link rel="apple-touch-icon" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/img/favicon_180.png"/><meta property="og:title" content="파이썬 : 네이버 도서"/><meta property="og:description" content="&#x27;파이썬&#x27;의 네이버 도서 검색 결과입니다."/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:url" content="https://search.shopping.naver.com/book/search?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC"/><meta name="next-head-count" content="10"/><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6f981f51784e4102.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6f981f51784e4102.css" data-n-g=""/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/585039363cbfcb1a.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/585039363cbfcb1a.css" data-n-p=""/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/1b0cdee5d7bbbd78.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/1b0cdee5d7bbbd78.css" data-n-p=""/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/c0b0c54e7553b563.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/c0b0c54e7553b563.css" data-n-p=""/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6ae063deaa19c1d7.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6ae063deaa19c1d7.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/webpack-0871768afe454a2c.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/framework-d136e45277b15cbf.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/main-d21d32a3a7973bed.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/pages/_app-6ede34ae0a2bb090.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/bf77ac6b-fe0e288b9d696158.js" defer=""> ...

# %% [markdown]
# # BeautifulSoup 설치 및 사용
# * 문자열로 응답받은 데이터를 HTML로 변환해주는 라이브러리
# * css selecter를 사용해서 HTML 안의 데이터를 추출할 수 있다.

# %% [markdown]
# conda install beautifulsoup4<br>
# pip install beautifulsoup4

# %% [markdown]
# lxml: c언어 기반의 빠른 parser(변환)
# * pip install lxml
# * conda install lxml

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(response, 'lxml') # 기본은 html.parser 이지만 빠른 속도를 위해서 lxml사용
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko"><head><meta charset="utf-8"/><meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><title>파이썬 : 네이버 도서</title><link href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/img/favicon.ico" rel="shortcut icon"/><link href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/img/favicon_180.png" rel="apple-touch-icon"/><meta content="파이썬 : 네이버 도서" property="og:title"/><meta content="'파이썬'의 네이버 도서 검색 결과입니다." property="og:description"/><meta content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png" property="og:image"/><meta content="https://search.shopping.naver.com/book/search?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC" property="og:url"/><meta content="10" name="next-head-count"/><link href="https://static.nid.naver.com" rel="preconnect"/><link href="https://lcs.naver.com" rel="preconnect"/><link href="http://shopping.phinf.naver.net" rel="preconnect"/><link href="https://ssl.pstatic.net" rel="preconnect"/><link href="https://shopping-phinf.pstatic.net" rel="preconnect"/><link href="https://volts.shopping.naver.com" rel="preconnect"/><link as="style" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6f981f51784e4102.css" rel="preload"/><link data-n-g="" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6f981f51784e4102.css" rel="stylesheet"/><link as="style" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/585039363cbfcb1a.css" rel="preload"/><link data-n-p="" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/585039363cbfcb1a.css" rel="stylesheet"/><link as="style" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/1b0cdee5d7bbbd78.css" rel="preload"/><link data-n-p="" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/1b0cdee5d7bbbd78.css" rel="stylesheet"/><link as="style" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/c0b0c54e7553b563.css" rel="preload"/><link data-n-p="" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/c0b0c54e7553b563.css" rel="stylesheet"/><link as="style" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6ae063deaa19c1d7.css" rel="preload"/><link data-n-p="" href="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/css/6ae063deaa19c1d7.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/webpack-0871768afe454a2c.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/framework-d136e45277b15cbf.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/main-d21d32a3a7973bed.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/pages/_app-6ede34ae0a2bb090.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/book-search/book-search-230907-104544/_next/static/chunks/bf77ac6b-fe0e288b9d696158.js"></script><script defer=""  ...

# %%
soup.select_one('title').text
# Out:
# '파이썬 : 네이버 도서'

# %% [markdown]
# # BeautifulSoup 모듈로 원하는 자료 가져오는법
# * find_all(), find(): 태그 기반으로 찾는 필터
#   * find_all(): 결과값이 list로 저장
#   * find(): 단일 값 저장
# * select(), select_one(): css셀렉터를 기반으로 찾는 필터
#   * select(): 결과값이 list로 저장
#   * select_one(): 단일 값 저장

# %%
# Out:
# [<span class="bookPrice_price__zr5dh">최저<!-- --> <em>24,700</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>23,750</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>31,500</em>원</span>,
#  <span class="bookPrice_price__zr5dh">구매<!-- --> <em>25,200</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>20,700</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>19,800</em>원</span>,
#  <span class="bookPrice_price__zr5dh">구매<!-- --> <em>15,840</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>26,100</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>26,100</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>22,500</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>15,300</em>원</span>,
#  <span class="bookPrice_price__zr5dh">구매<!-- --> <em>15,300</em>원</span>,
#  <span class="bookPrice_price__zr5dh">최저<!-- --> <em>30,400</em>원</span>]

# %%
soup.find("span", "bookListItem_text__bglOw").text
# Out:
# '파이썬과 데이터 과학 (파이썬으로 시작하는 데이터 과학과 기계학습)'

# %%
title = soup.find("span", "bookListItem_text__bglOw").text
ranking = soup.find("div", "bookListItem_feature__txTlp").text
author = soup.find("span", "bookListItem_define_data__kKD8t").text # 저자명
pubulisher = soup.find("div", "bookListItem_detail_publish__FgPYQ").find("span", "bookListItem_define_data__kKD8t").text # 출판사
starpoint = soup.find("div", "bookListItem_grade__tywh2").text[2:5]
price = soup.find("span", "bookPrice_price__zr5dh").find("em").text
print(title, ranking, author, pubulisher, starpoint, price)
# Out:
# 파이썬과 데이터 과학 (파이썬으로 시작하는 데이터 과학과 기계학습) 컴퓨터/IT 96위 천인국, 박동규 생능출판 5.0 24,700

# %%
book_list = soup.find("ul", "list_book").find_all("li")

# %%
book_list[2].find("span", "bookListItem_text__bglOw").text
# Out:
# '코딩 뇌를 깨우는 파이썬 (문제 해결 능력을 키우는 컴퓨팅 사고부터 알고리즘, 데이터 분석, 머신러닝까지)'

# %%
if len(find_all("span", "bookPrice_price__zr5dh")) < 2:
    price1 = .find_all("span", "bookPrice_price__zr5dh")[0].text 
else:
    price1 = .find_all("span", "bookPrice_price__zr5dh")[0].text
    price2 = .find_all("span", "bookPrice_price__zr5dh")[1].text
# Out:
# '구매 25,200원'

# %% [markdown]
# # book_list에서 10권의 제목, 랭킹, 저자 , 출판사, 가격 등 정보 추출해서 모으기
# ## 추출한 정보는 pandas 데이터프레임으로 변환하기

# %% [markdown]
# * 반복문 돌리기
# * 예외처리하기
# * 데이터 프레임으로 만들기

# %%
result = []
for book in book_list:
    title = book.find("span", "bookListItem_text__bglOw").text
    ranking = book.find("div", "bookListItem_feature__txTlp").text if book.find("div", "bookListItem_feature__txTlp") != None else "None"
    author = book.find("span", "bookListItem_define_data__kKD8t").text # 저자명
    pubulisher = book.find("div", "bookListItem_detail_publish__FgPYQ").find("span", "bookListItem_define_data__kKD8t").text # 출판사
    if book.find("div", "bookListItem_grade__tywh2") != None:
        starpoint = book.find("div", "bookListItem_grade__tywh2").text[2:5]
    else:
        starpoint = 0
    if len(book.find_all("span", "bookPrice_price__zr5dh")) < 2:
        price1 = book.find_all("span", "bookPrice_price__zr5dh")[0].find("em").text
        price2 = "None"
    else:
        price1 = book.find_all("span", "bookPrice_price__zr5dh")[0].find("em").text
        price2 = book.find_all("span", "bookPrice_price__zr5dh")[1].find("em").text
    result.append([title, ranking, author, pubulisher, starpoint, price1, price2])
result
# Out:
# [['파이썬과 데이터 과학 (파이썬으로 시작하는 데이터 과학과 기계학습)',
#   '컴퓨터/IT 96위',
#   '천인국, 박동규',
#   '생능출판',
#   '5.0',
#   '24,700',
#   'None'],
#  ['두근두근 파이썬 (만들면서 배우는)', '컴퓨터/IT 47위', '천인국', '생능출판', '4.7', '23,750', 'None'],
#  ['코딩 뇌를 깨우는 파이썬 (문제 해결 능력을 키우는 컴퓨팅 사고부터 알고리즘, 데이터 분석, 머신러닝까지)',
#   '컴퓨터/IT 86위',
#   '존 V. 구태그',
#   '한빛미디어',
#   0,
#   '31,500',
#   '25,200'],
#  ['나는 파이썬으로 머신러닝한다 2 (인공지능 자신감 UP 인공지능 약간 매운맛)',
#   '컴퓨터/IT 100위',
#   '장병철, 이지항 외 2명',
#   '씨마스',
#   '5.0',
#   '20,700',
#   'None'],
#  ['혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)',
#   '컴퓨터/IT 10위',
#   '윤인성',
#   '한빛미디어',
#   '4.9',
#   '19,800',
#   '15,840'],
#  ['파이썬으로 쉽게 배우는 자료구조 (개정판)',
#   '컴퓨터/IT 51위',
#   '최영규, 천인국',
#   '생능출판',
#   '3.0',
#   '26,100',
#   'None'],
#  ['디딤돌 파이썬 (구조적 프로그래밍으로 설명한 파이썬 기초)',
#   'None',
#   '이찬수',
#   '인피니티북스',
#   0,
#   '26,100',
#   'None'],
#  ['파이썬 스타트 (AI로 가는 첫걸음)', 'None', '박희재', '인피니티북스', 0, '22,500', 'None'],
#  ['자기주도 파이썬 (정보영재 및 올림피아드를 위한 최적의 입문서)',
#   'None',
#   '한컴에듀케이션 알고리즘연구소',
#   '복두출판사',
#   '5.0',
#   '15,300',
#   '15,300'],
#  ['파이썬', 'None', '홍의경', '생능출판', 0, '30,400', 'None']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(result, columns=['title', 'ranking', 'author', 'pubulisher', 'starpoint', 'paper', 'ebook'])
df
# Out:
#                                                title      ranking  \
# 0              파이썬과 데이터 과학 (파이썬으로 시작하는 데이터 과학과 기계학습)   컴퓨터/IT 96위
# 1                                두근두근 파이썬 (만들면서 배우는)   컴퓨터/IT 47위
# 2  코딩 뇌를 깨우는 파이썬 (문제 해결 능력을 키우는 컴퓨팅 사고부터 알고리즘, 데이...   컴퓨터/IT 86위
# 3        나는 파이썬으로 머신러닝한다 2 (인공지능 자신감 UP 인공지능 약간 매운맛)  컴퓨터/IT 100위
# 4               혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)   컴퓨터/IT 10위
# 5                            파이썬으로 쉽게 배우는 자료구조 (개정판)   컴퓨터/IT 51위
# 6                   디딤돌 파이썬 (구조적 프로그래밍으로 설명한 파이썬 기초)         None
# 7                               파이썬 스타트 (AI로 가는 첫걸음)         None
# 8                자기주도 파이썬 (정보영재 및 올림피아드를 위한 최적의 입문서)         None
# 9                                                파이썬         None
#
#             author pubulisher starpoint   paper   ebook
# 0         천인국, 박동규       생능출판       5.0  24,700    None
# 1              천인국       생능출판       4.7  23,750    None
# 2         존 V. 구태그      한빛미디어         0  31,500  25,200
# 3    장병철, 이지항 외 2명        씨마스       5.0  20,700    None
# 4              윤인성      한빛미디어       4.9  19,800  15,840
# 5         최영규, 천인국       생능출판       3.0  26,100    None
# 6              이찬수     인피니티북스         0  26,100    None
# 7              박희재     인피니티북스         0  22,500    None
# 8  한컴에듀케이션 알고리즘연구소      복두출판사       5.0  15,300  15,300
# 9              홍의경       생능출판         0  30,400    None

# %% [markdown]
# # select, select_one을 이용해서 자료 추출하기

# %%
book_list2 = soup.select("ul.list_book > li")

# %%
len(book_list2)
# Out:
# 10

# %%
result2 = []
for book in book_list2:
    title = book.select_one(".bookListItem_text__bglOw").text
    ranking = book.select_one(".bookListItem_feature__txTlp").text if book.select_one(".bookListItem_feature__txTlp") != None else None
    author = book.select_one(".bookListItem_define_data__kKD8t").text
    publisher = book.select_one("div.bookListItem_detail_publish__FgPYQ > span.bookListItem_define_data__kKD8t").text
    pub_date = book.select_one(".bookListItem_detail_date___byvG").text
    starpoint = book.select_one(".bookListItem_grade__tywh2").text[2:5] if book.select_one(".bookListItem_grade__tywh2") != None else 0
    reviews = book.select_one(".bookListItem_reviewer__kwofa").text.strip("() ") if book.select_one(".bookListItem_reviewer__kwofa") != None else 0
    
    if len(book.select(".bookPrice_price__zr5dh")) == 2:
        book_price = book.select(".bookPrice_price__zr5dh")[0].select_one("em").text
        ebook_price = book.select(".bookPrice_price__zr5dh")[1].select_one("em").text
    else:
        book_price = book.select(".bookPrice_price__zr5dh")[0].select_one("em").text
    result2.append([title, ranking, author, publisher, pub_date, starpoint, reviews, book_price, ebook_price])

# %%
len(result2)
# Out:
# 10

# %%
import pandas as pd

# %%
df2 = pd.DataFrame(result2, columns=['title', 'ranking', 'author', 'publisher', 'pub_date', 'starpoint', 'reviews', 'book_price', 'ebook_price'])
df2
# Out:
#                                                title      ranking  \
# 0              파이썬과 데이터 과학 (파이썬으로 시작하는 데이터 과학과 기계학습)   컴퓨터/IT 96위
# 1                                두근두근 파이썬 (만들면서 배우는)   컴퓨터/IT 47위
# 2  코딩 뇌를 깨우는 파이썬 (문제 해결 능력을 키우는 컴퓨팅 사고부터 알고리즘, 데이...   컴퓨터/IT 86위
# 3        나는 파이썬으로 머신러닝한다 2 (인공지능 자신감 UP 인공지능 약간 매운맛)  컴퓨터/IT 100위
# 4               혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)   컴퓨터/IT 10위
# 5                            파이썬으로 쉽게 배우는 자료구조 (개정판)   컴퓨터/IT 51위
# 6                   디딤돌 파이썬 (구조적 프로그래밍으로 설명한 파이썬 기초)         None
# 7                               파이썬 스타트 (AI로 가는 첫걸음)         None
# 8                자기주도 파이썬 (정보영재 및 올림피아드를 위한 최적의 입문서)         None
# 9                                                파이썬         None
#
#             author publisher     pub_date starpoint reviews book_price  \
# 0         천인국, 박동규      생능출판  2020.12.28.       5.0      10     24,700
# 1              천인국      생능출판  2023.01.05.       4.7       3     23,750
# 2         존 V. 구태그     한빛미디어  2023.08.30.         0       0     31,500
# 3    장병철, 이지항 외 2명       씨마스  2023.09.01.       5.0       1     20,700
# 4              윤인성     한빛미디어  2022.06.01.       4.9      19     19,800
# 5         최영규, 천인국      생능출판  2023.06.26.       3.0       1     26,100
# 6              이찬수    인피니티북스  2022.08.23.         0       0     26,100
# 7              박희재    인피니티북스  2022.06.28.         0       0     22,500
# 8  한컴에듀케이션 알고리즘연구소     복두출판사  2022.11.15.       5.0       2     15,300
# 9              홍의경      생능출판  2022.03.09.         0       0     30,400
#
#   ebook_price
# 0      15,300
# 1      15,300
# 2      25,200
# 3      25,200
# 4      15,840
# 5      15,840
# 6      15,840
# 7      15,840
# 8      15,300
# 9      15,300

# %%
# Out:
# '19,800'

# %%
# Out:
# '15,840'
