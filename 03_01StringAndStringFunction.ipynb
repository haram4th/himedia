# %% [markdown]
# # 문자열 사용하기, 문자열 함수

# %% [markdown]
# ### 데이터 분석을 할 때 웹에서 가져오는 데이터는 기본적으로 문자열 형태가 많음
# ### 문자열을 얼마나 잘 다루느냐 == 데이터 전처리 속도를 좌우 함

# %% [markdown]
# ## 1. 문자열 사용하기의 기본

# %% [markdown]
# ### ' ' 따옴표 안에 문자을 넣는다. 큰따옴표 작은따옴표 모두 가능

# %%
hello = 'Hello, world!'
hello
# Out:
# 'Hello, world!'

# %% [markdown]
# ### 한글도 가능 " " 큰따옴표 사용

# %%
hello2 = "안녕하세요"
hello2
# Out:
# '안녕하세요'

# %% [markdown]
# ### 여러 줄로 된 문자열 사용하기 ''' '''  또는  """ """

# %%
hello3 = '''Hello, world! 
안녕하세요. 
Python 수업입니다.'''
print(hello3)
# Out:
# Hello, world!
# 안녕하세요.
# Python 수업입니다.

# %%
hello4 = '''여러 줄로 문자열을 넣을 때는
작은따옴표 3개 또는
큰따옴표 3개를 사용합니다. 
'''
print(hello4)
# Out:
# 여러 줄로 문자열을 넣을 때는
# 작은따옴표 3개 또는
# 큰따옴표 3개를 사용합니다.

# %% [markdown]
# ### 문자열 안에 작은따옴표나 큰따옴표 포함하기

# %% [markdown]
# 큰따옴표 안에 작은 따옴표 넣기

# %%
h5 = "'Hello Python'"
print(h5)
# Out:
# 'Hello Python'

# %% [markdown]
# 작은 따옴표 안에 큰따옴표 넣기

# %%
h6 = '"안녕 파이썬"'
print(h6)
# Out:
# "안녕 파이썬"

# %% [markdown]
# 이스케이프문자( \ ) 사용하기

# %%
h7 = 'Python isn\'t difficult'
print(h7)
# Out:
# Python isn't difficult

# %% [markdown]
# 자주 쓰는 이스케이프 문자 \n(줄바꿈), \t(탭), \r(캐리지리턴-줄 맨 왼쪽으로 커서이동)

# %%
h8 = "파이썬에서 줄바꿈은\\n으로 합니다.\n\n\n줄 바꿈 끝"
print(h8)
# Out:
# 파이썬에서 줄바꿈은\n으로 합니다.
#
#
# 줄 바꿈 끝

# %%
h9 = "탭으로 공간을 띄우는 것은\\t \t로 합니다."
print(h9)
# Out:
# 탭으로 공간을 띄우는 것은\t 	로 합니다.

# %%
h10 = "마지막으로 캐리지 리턴은 \\r입니다.\n 커서가 같은 줄 가장 앞으로 이동하기 때문에  \r글자가 겹쳐져서 지워졌습니다."
print(h10)
# Out:
# 마지막으로 캐리지 리턴은 \r입니다.
# 글자가 겹쳐져서 지워졌습니다.

# %% [markdown]
# ## 인덱스와 문자열

# %% [markdown]
# ### 문자열은 여러개의 문자가 줄을 선 것과 같이 이어진 글자의 모음이므로 왼쪽부터 번호를 매길 수 있음

# %%
h11 = "문자열에는 왼쪽부터 번호를 매길 수 있으며 시작은 0번부터 입니다."

# %%
print(h11[0]); print(h11[1]); print(h11[2]); print(h11[3])
# Out:
# 문
# 자
# 열
# 에

# %% [markdown]
# ### 문자열 / 데이터의 길이를 볼 때는 len()함수 사용

# %%
len(h11)
# Out:
# 37

# %%
h11[35]
# Out:
# '다'

# %% [markdown]
# ### 인덱스를 활용한 문자열 슬라이싱

# %% [markdown]
# 위의 인덱스를 활용하면 문자열이 일부분만 잘라서 가져오는 슬라이싱이 가능합니다.

# %%
# h11변수에 저장된 문자열 인덱스 0번부터 10번까지
h11[0:10]
# Out:
# '문자열에는 왼쪽부터'

# %%
h11
# Out:
# '문자열에는 왼쪽부터 번호를 매길 수 있으며 시작은 0번부터 입니다.'

# %%
h11[5:]
# Out:
# ' 왼쪽부터 번호를 매길 수 있으며 시작은 0번부터 입니다.'

# %%
h11[:10]
# Out:
# '문자열에는 왼쪽부터'

# %%
h11[10:30]
# Out:
# ' 번호를 매길 수 있으며 시작은 0번'

# %% [markdown]
# ## 2. 문자열 함수

# %% [markdown]
# 문자열을 조작하는데는 활용되는 여러가지 함수가 있습니다. 이 함수들을 잘 사용해야 데이터 전처리를 효과적으로 할 수 있습니다. 특히 .split(), .join(), .strip() 등의 함수들을 잘 익혀두시기 바랍니다.

# %% [markdown]
# ## 1) 문자열 바꾸기

# %% [markdown]
# ### .replace(a,b) a를 찾아 b로 바꿈 단, 원본은 바꾸지 않기 때문에 따로 저장 필요

# %%
print(h5)
# Out:
# 'Hello Python'

# %% [markdown]
# h5 변수에서 Python을 찾아 World로 변경

# %%
h5.replace('Python', 'World')
# Out:
# "'Hello World'"

# %% [markdown]
# 그냥 .replace()함수를 쓰면 결과만 변경되어 출력되고 원본은 그대로있기 때문에 다시 저장해주어야 함.

# %%
h5
# Out:
# "'Hello Python'"

# %%
h5 = h5.replace('Python', 'World')
h5
# Out:
# "'Hello World'"

# %%
h5
# Out:
# "'Hello World'"

# %% [markdown]
# ## 2) 문자바꾸기
# ### str.maketrans('바꿀문자','새문자', '추가로 없앨문자') 로 변환테이블 생성 후 translate로 문자를 찾아 바꿈

# %%
table = str.maketrans('abcdefg','1234567', 'lor')

# %%
h5.translate(table)
# Out:
# "'H5 W4'"

# %% [markdown]
# ## 3) 문자열 분리하기

# %% [markdown]
# ### .split()은 공백을 기준으로 문자열을 분리해 리스트로 만들어 줌.

# %%
h11
# Out:
# '문자열에는 왼쪽부터 번호를 매길 수 있으며 시작은 0번부터 입니다.'

# %%
h11.split()
# Out:
# ['문자열에는', '왼쪽부터', '번호를', '매길', '수', '있으며', '시작은', '0번부터', '입니다.']

# %%
L1 = h11.split()
L1
# Out:
# ['문자열에는', '왼쪽부터', '번호를', '매길', '수', '있으며', '시작은', '0번부터', '입니다.']

# %% [markdown]
# ### .split(기준문자)는 기준문자를 기준으로 문자열을 분리해 리스트로 만들어 줌

# %%
h12 = "사과, 배, 포도, 파인애플, 망고, 오렌지"

# %%
L2 = h12.split(',')
L2
# Out:
# ['사과', ' 배', ' 포도', ' 파인애플', ' 망고', ' 오렌지']

# %% [markdown]
# ### .join(리스트)로 문자열 리스트 연결하기

# %%
L2
# Out:
# ['사과', ' 배', ' 포도', ' 파인애플', ' 망고', ' 오렌지']

# %%
L3=' '.join(L2)
L3
# Out:
# '사과  배  포도  파인애플  망고  오렌지'

# %%
L3
# Out:
# '사과  배  포도  파인애플  망고  오렌지'

# %%
L4 = ','.join(L2)
L4
# Out:
# '사과, 배, 포도, 파인애플, 망고, 오렌지'

# %%
L5 = ':'.join(L2)
L5
# Out:
# '사과: 배: 포도: 파인애플: 망고: 오렌지'

# %%
L6 = ['iron man', 'spider-man', 'black widow', 'hulk']

# %%
L7 = ' VS '.join(L6)
L7
# Out:
# 'iron man VS spider-man VS black widow VS hulk'

# %% [markdown]
# ## 4) 소문자를 대문자로 대문자를 소문자로 바꾸기

# %% [markdown]
# ### 소문자를 대문자로 .upper() , 대문자를 소문자로 .lower()

# %%
L7
# Out:
# 'iron man VS spider-man VS black widow VS hulk'

# %%
L7.upper()
# Out:
# 'IRON MAN VS SPIDER-MAN VS BLACK WIDOW VS HULK'

# %%
L7.lower()
# Out:
# 'iron man vs spider-man vs black widow vs hulk'

# %%
L7
# Out:
# 'iron man VS spider-man VS black widow VS hulk'

# %% [markdown]
# ## 5) 왼쪽, 오른쪽, 양쪽 공백/특정 문자 삭제하기

# %% [markdown]
# ### 왼쪽 .lstrip() , 오른쪽 .rstrip(), 양쪽 .strip()

# %%
h13 = "     공백이 있는 문자열      "
h13
# Out:
# '     공백이 있는 문자열      '

# %%
h13.lstrip()
# Out:
# '공백이 있는 문자열      '

# %%
h13.rstrip()
# Out:
# '     공백이 있는 문자열'

# %%
h13.strip()
# Out:
# '공백이 있는 문자열'

# %%
h13
# Out:
# '     공백이 있는 문자열      '

# %%
h14 = " ... , 공백과 특수문자가 같이 있는 문자열 !! ...   "
h14
# Out:
# ' ... , 공백과 특수문자가 같이 있는 문자열 !! ...   '

# %%
h14.lstrip('.," "')
# Out:
# '공백과 특수문자가 같이 있는 문자열 !! ...   '

# %%
h14.rstrip('.," "!')
# Out:
# ' ... , 공백과 특수문자가 같이 있는 문자열'

# %%
a =  '.," "!'

# %%
h14.strip('.," "!')
# Out:
# '공백과 특수문자가 같이 있는 문자열'

# %%
h14.strip(a)
# Out:
# '공백과 특수문자가 같이 있는 문자열'

# %% [markdown]
# ## 6) string 모듈을 사용해서 특수문자 간단하게 삭제하기

# %% [markdown]
# ### 파이썬에서는 import 명령어를 사용해서 외부 모듈을 불러올 수 있다.
# ### 여러 모듈 중 string 모듈을 불러와 punctuation을 사용하면 특수문자를 간단하게 삭제가능

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
h14.translate(str.maketrans("","",string.punctuation))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-008951ff8063> in <module>
# ----> 1 h14.translate(str.maketrans("","",string.punctuation))
#
# NameError: name 'h14' is not defined

# %% [markdown]
# ## 메서드 체이닝으로 여러함수 동시에 사용하기

# %% [markdown]
# 위에서 string.punctuation으로 특수문자는 없앴지만 양옆의 공백은 그대로 남아있음.<br/>
# .translate 뒤에 바로 .strip()을 연이어 사용해 양쪽 공백도 없앰

# %%
h14.translate(str.maketrans("","",string.punctuation)).strip()
# Out:
# '공백과 특수문자가 같이 있는 문자열'

# %% [markdown]
# # 연습문제
# ## 아래의 문장들에서 특수문자와 2칸 이상의 공백 그리고 좌우 공백을 제거하시오.

# %% [markdown]
# 아래의 예제 데이터는 호텔스 닷컴의 사용자 리뷰를 크롤링 한 원본입니다. JSON 형태로 받은 원본 데이터에서 사용자 리뷰쪽 데이터만 따로 정리한 것인데 댓글 감성리뷰를 하기에는 특수문자와 구두점이 너무 많아 데이터의 정리가 필요합니다. 아래의 데이터를 문자만 나오도록 정리해 보세요. 위에서 배운 문자열 사용법과 함수는 이런 작업을 하는데 사용되고 데이터 전처리에서 반드시 필요합니다.

# %% [markdown]
# ### 문제1

# %%
test1 = '''344,622642,더 호텔 수 (THE HOTEL SOO),family,1박 가족 여행,2018년 5월 21일,8.0,"위치 : 이순신 광장과는 반대편이라 차량으로 이동해야 합니다. 루프탑에서의
바다 경치는 좋습니다.
시설 : 깔끔하고 좋습니다. 패밀리룸을 사용 했는데 저녁6시쯤 갔더니 마지막 방이라며 2층을 배정 받았습니다. 창문을 여니 약간 쓰레기 냄새가 났고 바다가 보이지 않습니다.        
루프탑 : 바베큐 세트가 저렴 했던거 같고 경치가 좋습니다. 수영장도 있었는데 계절이 아닌지.... 
    하지만 여름이면 좋을것 같습니다. 주차장은 장소가 넓지 않았던거 같고, 저녁에 나갔다 왔더니 야외 공터에 차를 대라고 하였습니다.    
주말 저녁이라 그런지 가격을 제법 비싸게 준거 같은데... 2층이라 마음에 들지 않았습니다. 옆에 조선소 같은게 있어 쫌 보기에 좋지 않았습니다......................................
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ""'''

# %% [markdown]
# 이스케이프 문자인 \\n나 \\t 도 위에서는 보이지 않지만 아래 처럼 출력해보면 데이터 중간중간 들어있고 모두 삭제되어야 합니다.

# %%
test1
# Out:
# '344,622642,더 호텔 수 (THE HOTEL SOO),family,1박 가족 여행,2018년 5월 21일,8.0,"위치 : 이순신 광장과는 반대편이라 차량으로 이동해야 합니다. 루프탑에서의\n바다 경치는 좋습니다.\n시설 : 깔끔하고 좋습니다. 패밀리룸을 사용 했는데 저녁6시쯤 갔더니 마지막 방이라며 2층을 배정 받았습니다. 창문을 여니 약간 쓰레기 냄새가 났고 바다가 보이지 않습니다.        \n루프탑 : 바베큐 세트가 저렴 했던거 같고 경치가 좋습니다. 수영장도 있었는데 계절이 아닌지.... \n    하지만 여름이면 좋을것 같습니다. 주차장은 장소가 넓지 않았던거 같고, 저녁에 나갔다 왔더니 야외 공터에 차를 대라고 하였습니다.    \n주말 저녁이라 그런지 가격을 제법 비싸게 준거 같은데... 2층이라 마음에 들지 않았습니다. 옆에 조선소 같은게 있어 쫌 보기에 좋지 않았습니다......................................\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
t1list = test1.split(',')

# %%
t1list[7]
# Out:
# '"위치 : 이순신 광장과는 반대편이라 차량으로 이동해야 합니다. 루프탑에서의\n바다 경치는 좋습니다.\n시설 : 깔끔하고 좋습니다. 패밀리룸을 사용 했는데 저녁6시쯤 갔더니 마지막 방이라며 2층을 배정 받았습니다. 창문을 여니 약간 쓰레기 냄새가 났고 바다가 보이지 않습니다.        \n루프탑 : 바베큐 세트가 저렴 했던거 같고 경치가 좋습니다. 수영장도 있었는데 계절이 아닌지.... \n    하지만 여름이면 좋을것 같습니다. 주차장은 장소가 넓지 않았던거 같고'

# %%
temp = t1list[7]+t1list[8]
temp
# Out:
# '"위치 : 이순신 광장과는 반대편이라 차량으로 이동해야 합니다. 루프탑에서의\n바다 경치는 좋습니다.\n시설 : 깔끔하고 좋습니다. 패밀리룸을 사용 했는데 저녁6시쯤 갔더니 마지막 방이라며 2층을 배정 받았습니다. 창문을 여니 약간 쓰레기 냄새가 났고 바다가 보이지 않습니다.        \n루프탑 : 바베큐 세트가 저렴 했던거 같고 경치가 좋습니다. 수영장도 있었는데 계절이 아닌지.... \n    하지만 여름이면 좋을것 같습니다. 주차장은 장소가 넓지 않았던거 같고 저녁에 나갔다 왔더니 야외 공터에 차를 대라고 하였습니다.    \n주말 저녁이라 그런지 가격을 제법 비싸게 준거 같은데... 2층이라 마음에 들지 않았습니다. 옆에 조선소 같은게 있어 쫌 보기에 좋지 않았습니다......................................\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
temp = temp.replace('\n',"").replace('  '," ").replace(':', "").replace('(', "").replace(')', "").replace('...',"").strip('"." "')

# %%
temp
# Out:
# '위치  이순신 광장과는 반대편이라 차량으로 이동해야 합니다. 루프탑에서의바다 경치는 좋습니다.시설  깔끔하고 좋습니다. 패밀리룸을 사용 했는데 저녁6시쯤 갔더니 마지막 방이라며 2층을 배정 받았습니다. 창문을 여니 약간 쓰레기 냄새가 났고 바다가 보이지 않습니다.    루프탑  바베큐 세트가 저렴 했던거 같고 경치가 좋습니다. 수영장도 있었는데 계절이 아닌지.   하지만 여름이면 좋을것 같습니다. 주차장은 장소가 넓지 않았던거 같고 저녁에 나갔다 왔더니 야외 공터에 차를 대라고 하였습니다.  주말 저녁이라 그런지 가격을 제법 비싸게 준거 같은데 2층이라 마음에 들지 않았습니다. 옆에 조선소 같은게 있어 쫌 보기에 좋지 않았습니다'

# %%
review_text1 = temp.replace('    '," ").replace('   '," ").replace('  '," ")
review_text1
# Out:
# '위치 이순신 광장과는 반대편이라 차량으로 이동해야 합니다. 루프탑에서의바다 경치는 좋습니다.시설 깔끔하고 좋습니다. 패밀리룸을 사용 했는데 저녁6시쯤 갔더니 마지막 방이라며 2층을 배정 받았습니다. 창문을 여니 약간 쓰레기 냄새가 났고 바다가 보이지 않습니다. 루프탑 바베큐 세트가 저렴 했던거 같고 경치가 좋습니다. 수영장도 있었는데 계절이 아닌지. 하지만 여름이면 좋을것 같습니다. 주차장은 장소가 넓지 않았던거 같고 저녁에 나갔다 왔더니 야외 공터에 차를 대라고 하였습니다. 주말 저녁이라 그런지 가격을 제법 비싸게 준거 같은데 2층이라 마음에 들지 않았습니다. 옆에 조선소 같은게 있어 쫌 보기에 좋지 않았습니다'

# %% [markdown]
# ### 문제2

# %%
test2= "18062,427535,파크 하얏트 부산 (Park Hyatt Busan),family,2박 가족 여행,2019년 12월 29일,10.0,결혼 1주년 기념으로 아이랑 신랑이랑 다녀왔어요~ 룸컨디션 너무 좋았고 뷰가 최고였습니다! 2박 머물렀는데 청소도 깔끔하게 해주시고 애기가 이불에 살짝 토했는데도 바로 갈아주시고 좋았습니다~ 대신 창가쪽 커튼 한쪽이 떨어져있어서 조금 거슬렸구요... 창가에 침실이 있다보니 암막커튼을 치지 않으면 조금 쌀쌀한 느낌은 있었어요! 아 그리고 아기때문에 침대에 가드를 부탁드렸는데 가드가 너무 별로였습니다... 가드 구실을 못하고 넘 허술하게 매트리스 아래 그냥 끼워진거라 아기가 밤새 두번이나 가드사이에 빠졌습니다... 이점 좀 아쉬워요 ! 그 외에는 다이닝룸 리빙룸, 바까지 모두 이용했는데 서비스 좋았습니다~~!"

# %%
test2
# Out:
# '18062,427535,파크 하얏트 부산 (Park Hyatt Busan),family,2박 가족 여행,2019년 12월 29일,10.0,결혼 1주년 기념으로 아이랑 신랑이랑 다녀왔어요~ 룸컨디션 너무 좋았고 뷰가 최고였습니다! 2박 머물렀는데 청소도 깔끔하게 해주시고 애기가 이불에 살짝 토했는데도 바로 갈아주시고 좋았습니다~ 대신 창가쪽 커튼 한쪽이 떨어져있어서 조금 거슬렸구요... 창가에 침실이 있다보니 암막커튼을 치지 않으면 조금 쌀쌀한 느낌은 있었어요! 아 그리고 아기때문에 침대에 가드를 부탁드렸는데 가드가 너무 별로였습니다... 가드 구실을 못하고 넘 허술하게 매트리스 아래 그냥 끼워진거라 아기가 밤새 두번이나 가드사이에 빠졌습니다... 이점 좀 아쉬워요 ! 그 외에는 다이닝룸 리빙룸, 바까지 모두 이용했는데 서비스 좋았습니다~~!'

# %%
temp2 = test2.split(',')

# %%
temp2=temp2[7]+temp2[8]

# %%
temp2
# Out:
# '결혼 1주년 기념으로 아이랑 신랑이랑 다녀왔어요~ 룸컨디션 너무 좋았고 뷰가 최고였습니다! 2박 머물렀는데 청소도 깔끔하게 해주시고 애기가 이불에 살짝 토했는데도 바로 갈아주시고 좋았습니다~ 대신 창가쪽 커튼 한쪽이 떨어져있어서 조금 거슬렸구요... 창가에 침실이 있다보니 암막커튼을 치지 않으면 조금 쌀쌀한 느낌은 있었어요! 아 그리고 아기때문에 침대에 가드를 부탁드렸는데 가드가 너무 별로였습니다... 가드 구실을 못하고 넘 허술하게 매트리스 아래 그냥 끼워진거라 아기가 밤새 두번이나 가드사이에 빠졌습니다... 이점 좀 아쉬워요 ! 그 외에는 다이닝룸 리빙룸 바까지 모두 이용했는데 서비스 좋았습니다~~!'

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
review_text2 = temp2.translate(str.maketrans("","",string.punctuation)).strip()
review_text2
# Out:
# '결혼 1주년 기념으로 아이랑 신랑이랑 다녀왔어요 룸컨디션 너무 좋았고 뷰가 최고였습니다 2박 머물렀는데 청소도 깔끔하게 해주시고 애기가 이불에 살짝 토했는데도 바로 갈아주시고 좋았습니다 대신 창가쪽 커튼 한쪽이 떨어져있어서 조금 거슬렸구요 창가에 침실이 있다보니 암막커튼을 치지 않으면 조금 쌀쌀한 느낌은 있었어요 아 그리고 아기때문에 침대에 가드를 부탁드렸는데 가드가 너무 별로였습니다 가드 구실을 못하고 넘 허술하게 매트리스 아래 그냥 끼워진거라 아기가 밤새 두번이나 가드사이에 빠졌습니다 이점 좀 아쉬워요  그 외에는 다이닝룸 리빙룸 바까지 모두 이용했는데 서비스 좋았습니다'

# %% [markdown]
# ### 문제3

# %%
test3 = """112731,239840,서귀포 칼 호텔 (Seogwipo KAL Hotel),family,3박 가족 여행,2020년 11월 19일,8.0,넓디넓은 정원과 산책로 덕분에 코로나 시대 언택트 여행에 좋았구요. 조용하고 한적하게 잘 쉬었어요.
아무래도 서귀포가 제주시쪽보단 사람도 적어서 오히려 편하면서, 주변에 식당이나 까페, 편의점 갈때도 걸어서도 다녀올 입지라 좋습니다.
실내 수영장은 생각만큼? 작은 규모라 오히려 사람 없이 잘 놀았어요ㅎㅎ 
라운지바가 넓고 층고도 높아서 커피나 맥주 먹으며 쉬기에 좋고요.
매일 주시는 1.5리터 생수ㅎㅎ별거 아닐수 있지만 매우 감사했구요.
다만 층수가 낮은 방이어서 그런가 모기가 있었어요^^;; 그외에는 다 깨끗했구요. 
매트리스가 오래됐는지 묘하게 불편해서 허리가 아프긴 하더라고요;; 다행히? 세미온돌이라 바닥에서 자는게 오히려 나았고요
조식은...최근 후기가 다 별로라길래 하루만 가봤는데 역시;;ㅎ 뭐 저렴하기도 하지만.. 저는 나가서 먹었습니다."""

# %%
test3
# Out:
# '112731,239840,서귀포 칼 호텔 (Seogwipo KAL Hotel),family,3박 가족 여행,2020년 11월 19일,8.0,넓디넓은 정원과 산책로 덕분에 코로나 시대 언택트 여행에 좋았구요. 조용하고 한적하게 잘 쉬었어요.\n아무래도 서귀포가 제주시쪽보단 사람도 적어서 오히려 편하면서, 주변에 식당이나 까페, 편의점 갈때도 걸어서도 다녀올 입지라 좋습니다.\n실내 수영장은 생각만큼? 작은 규모라 오히려 사람 없이 잘 놀았어요ㅎㅎ \n라운지바가 넓고 층고도 높아서 커피나 맥주 먹으며 쉬기에 좋고요.\n매일 주시는 1.5리터 생수ㅎㅎ별거 아닐수 있지만 매우 감사했구요.\n다만 층수가 낮은 방이어서 그런가 모기가 있었어요^^;; 그외에는 다 깨끗했구요. \n매트리스가 오래됐는지 묘하게 불편해서 허리가 아프긴 하더라고요;; 다행히? 세미온돌이라 바닥에서 자는게 오히려 나았고요\n조식은...최근 후기가 다 별로라길래 하루만 가봤는데 역시;;ㅎ 뭐 저렴하기도 하지만.. 저는 나가서 먹었습니다.'

# %%
temp3 = test3.split(',')
temp3
# Out:
# ['112731',
#  '239840',
#  '서귀포 칼 호텔 (Seogwipo KAL Hotel)',
#  'family',
#  '3박 가족 여행',
#  '2020년 11월 19일',
#  '8.0',
#  '넓디넓은 정원과 산책로 덕분에 코로나 시대 언택트 여행에 좋았구요. 조용하고 한적하게 잘 쉬었어요.\n아무래도 서귀포가 제주시쪽보단 사람도 적어서 오히려 편하면서',
#  ' 주변에 식당이나 까페',
#  ' 편의점 갈때도 걸어서도 다녀올 입지라 좋습니다.\n실내 수영장은 생각만큼? 작은 규모라 오히려 사람 없이 잘 놀았어요ㅎㅎ \n라운지바가 넓고 층고도 높아서 커피나 맥주 먹으며 쉬기에 좋고요.\n매일 주시는 1.5리터 생수ㅎㅎ별거 아닐수 있지만 매우 감사했구요.\n다만 층수가 낮은 방이어서 그런가 모기가 있었어요^^;; 그외에는 다 깨끗했구요. \n매트리스가 오래됐는지 묘하게 불편해서 허리가 아프긴 하더라고요;; 다행히? 세미온돌이라 바닥에서 자는게 오히려 나았고요\n조식은...최근 후기가 다 별로라길래 하루만 가봤는데 역시;;ㅎ 뭐 저렴하기도 하지만.. 저는 나가서 먹었습니다.']

# %%
len(temp3[7:])
# Out:
# 3

# %%
temp3 = temp3[7] +temp3[8]+temp3[9]
temp3
# Out:
# '넓디넓은 정원과 산책로 덕분에 코로나 시대 언택트 여행에 좋았구요. 조용하고 한적하게 잘 쉬었어요.\n아무래도 서귀포가 제주시쪽보단 사람도 적어서 오히려 편하면서 주변에 식당이나 까페 편의점 갈때도 걸어서도 다녀올 입지라 좋습니다.\n실내 수영장은 생각만큼? 작은 규모라 오히려 사람 없이 잘 놀았어요ㅎㅎ \n라운지바가 넓고 층고도 높아서 커피나 맥주 먹으며 쉬기에 좋고요.\n매일 주시는 1.5리터 생수ㅎㅎ별거 아닐수 있지만 매우 감사했구요.\n다만 층수가 낮은 방이어서 그런가 모기가 있었어요^^;; 그외에는 다 깨끗했구요. \n매트리스가 오래됐는지 묘하게 불편해서 허리가 아프긴 하더라고요;; 다행히? 세미온돌이라 바닥에서 자는게 오히려 나았고요\n조식은...최근 후기가 다 별로라길래 하루만 가봤는데 역시;;ㅎ 뭐 저렴하기도 하지만.. 저는 나가서 먹었습니다.'

# %%
temp3 = temp3.translate(str.maketrans("","",string.punctuation)).strip()
temp3
# Out:
# '넓디넓은 정원과 산책로 덕분에 코로나 시대 언택트 여행에 좋았구요 조용하고 한적하게 잘 쉬었어요\n아무래도 서귀포가 제주시쪽보단 사람도 적어서 오히려 편하면서 주변에 식당이나 까페 편의점 갈때도 걸어서도 다녀올 입지라 좋습니다\n실내 수영장은 생각만큼 작은 규모라 오히려 사람 없이 잘 놀았어요ㅎㅎ \n라운지바가 넓고 층고도 높아서 커피나 맥주 먹으며 쉬기에 좋고요\n매일 주시는 15리터 생수ㅎㅎ별거 아닐수 있지만 매우 감사했구요\n다만 층수가 낮은 방이어서 그런가 모기가 있었어요 그외에는 다 깨끗했구요 \n매트리스가 오래됐는지 묘하게 불편해서 허리가 아프긴 하더라고요 다행히 세미온돌이라 바닥에서 자는게 오히려 나았고요\n조식은최근 후기가 다 별로라길래 하루만 가봤는데 역시ㅎ 뭐 저렴하기도 하지만 저는 나가서 먹었습니다'

# %%
temp3 = temp3.replace('\n'," ")

# %%
temp3 = temp3.replace('ㅎ',"")
temp3
# Out:
# '넓디넓은 정원과 산책로 덕분에 코로나 시대 언택트 여행에 좋았구요 조용하고 한적하게 잘 쉬었어요 아무래도 서귀포가 제주시쪽보단 사람도 적어서 오히려 편하면서 주변에 식당이나 까페 편의점 갈때도 걸어서도 다녀올 입지라 좋습니다 실내 수영장은 생각만큼 작은 규모라 오히려 사람 없이 잘 놀았어요  라운지바가 넓고 층고도 높아서 커피나 맥주 먹으며 쉬기에 좋고요 매일 주시는 15리터 생수별거 아닐수 있지만 매우 감사했구요 다만 층수가 낮은 방이어서 그런가 모기가 있었어요 그외에는 다 깨끗했구요  매트리스가 오래됐는지 묘하게 불편해서 허리가 아프긴 하더라고요 다행히 세미온돌이라 바닥에서 자는게 오히려 나았고요 조식은최근 후기가 다 별로라길래 하루만 가봤는데 역시 뭐 저렴하기도 하지만 저는 나가서 먹었습니다'
