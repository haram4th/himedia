# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ple
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ADsP/main/salary2.csv")
data.head()
# Out:
#    age   workclass      education  education-num       marital-status  \
# 0   25     Private           11th              7        Never-married
# 1   38     Private        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private   Some-college             10   Married-civ-spouse
# 4   18         NaN   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                 NaN    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   class
# 0             0              40   United-States   <=50K
# 1             0              50   United-States   <=50K
# 2             0              40   United-States    >50K
# 3             0              40   United-States    >50K
# 4             0              30   United-States   <=50K

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %% [markdown]
# ### 학력, 교육, 연수, 혼인상태, 직업정보가 있는 연봉데이터셋을 이용해 연봉 예측하기
# * age: 나이
# * workclass: 고용형태
# * education: 학력
# * education-num: 교육 기간
# * marital-status: 혼인상태
# * occupation: 직업
# * relationship: 가족관계
# * race: 인종
# * sex: 성별
# * capital-gain: 자산증가
# * capital-loss: 자산감소
# * hours-per-week: 주당 노동 시간
# * native-country: 본국
# * class: 연봉 - target(종속변수)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   education       48842 non-null  object
#  3   education-num   48842 non-null  int64
#  4   marital-status  48842 non-null  object
#  5   occupation      46033 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital-gain    48842 non-null  int64
#  10  capital-loss    48842 non-null  int64
#  11  hours-per-week  48842 non-null  int64
#  12  native-country  47985 non-null  object
#  13  class           48842 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
data.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  48842.000000   48842.000000  48842.000000  48842.000000    48842.000000
# mean      38.643585      10.078089   1079.067626     87.502314       40.422382
# std       13.710510       2.570973   7452.019058    403.004552       12.391444
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %%
data.isna().sum()
# Out:
# age                  0
# workclass         2799
# education            0
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# class                0
# dtype: int64

# %%
data['class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
data[data['workclass'].isna() == True]
# Out:
#        age workclass      education  education-num       marital-status  \
# 4       18       NaN   Some-college             10        Never-married
# 6       29       NaN        HS-grad              9        Never-married
# 13      58       NaN        HS-grad              9   Married-civ-spouse
# 22      72       NaN        7th-8th              4             Divorced
# 35      65       NaN        HS-grad              9   Married-civ-spouse
# ...    ...       ...            ...            ...                  ...
# 48811   35       NaN      Bachelors             13   Married-civ-spouse
# 48812   30       NaN      Bachelors             13        Never-married
# 48820   71       NaN      Doctorate             16   Married-civ-spouse
# 48822   41       NaN        HS-grad              9            Separated
# 48823   72       NaN        HS-grad              9   Married-civ-spouse
#
#       occupation    relationship                 race      sex  capital-gain  \
# 4            NaN       Own-child                White   Female             0
# 6            NaN       Unmarried                Black     Male             0
# 13           NaN         Husband                White     Male             0
# 22           NaN   Not-in-family                White   Female             0
# 35           NaN         Husband                White     Male             0
# ...          ...             ...                  ...      ...           ...
# 48811        NaN            Wife                White   Female             0
# 48812        NaN   Not-in-family   Asian-Pac-Islander   Female             0
# 48820        NaN         Husband                White     Male             0
# 48822        NaN   Not-in-family                Black   Female             0
# 48823        NaN         Husband                White     Male             0
#
#        capital-loss  hours-per-week  native-country   class
# 4                 0              30   United-States   <=50K
# 6                 0              40   United-States   <=50K
# 13                0              35   United-States   <=50K
# 22                0               6   United-States   <=50K
# 35                0              40   United-States   <=50K
# ...             ...             ...             ...     ...
# 48811             0              55   United-States    >50K
# 48812             0              99   United-States   <=50K
# 48820             0              10   United-States    >50K
# 48822             0              32   United-States   <=50K
# 48823             0              25   United-States   <=50K
#
# [2799 rows x 14 columns]

# %%
data[(data['workclass'].isna() == True) & (data['class'] == ' >50K')]
# Out:
#        age workclass      education  education-num       marital-status  \
# 89      41       NaN        Masters             14   Married-civ-spouse
# 182     28       NaN        HS-grad              9   Married-civ-spouse
# 274     53       NaN        HS-grad              9   Married-civ-spouse
# 505     38       NaN        HS-grad              9   Married-civ-spouse
# 781     62       NaN        HS-grad              9   Married-civ-spouse
# ...    ...       ...            ...            ...                  ...
# 48278   60       NaN   Some-college             10   Married-civ-spouse
# 48279   52       NaN           12th              8   Married-civ-spouse
# 48297   62       NaN        HS-grad              9   Married-civ-spouse
# 48811   35       NaN      Bachelors             13   Married-civ-spouse
# 48820   71       NaN      Doctorate             16   Married-civ-spouse
#
#       occupation relationship    race      sex  capital-gain  capital-loss  \
# 89           NaN         Wife   White   Female          7688             0
# 182          NaN    Own-child   White   Female             0             0
# 274          NaN      Husband   White     Male             0             0
# 505          NaN         Wife   White   Female             0          1887
# 781          NaN      Husband   White     Male          5178             0
# ...          ...          ...     ...      ...           ...           ...
# 48278        NaN      Husband   White     Male             0             0
# 48279        NaN         Wife   Black   Female             0             0
# 48297        NaN      Husband   White     Male             0             0
# 48811        NaN         Wife   White   Female             0             0
# 48820        NaN      Husband   White     Male             0             0
#
#        hours-per-week  native-country  class
# 89                 10   United-States   >50K
# 182                38   United-States   >50K
# 274                35   United-States   >50K
# 505                10   United-States   >50K
# 781                40   United-States   >50K
# ...               ...             ...    ...
# 48278              12   United-States   >50K
# 48279              40   United-States   >50K
# 48297              40   United-States   >50K
# 48811              55   United-States   >50K
# 48820              10   United-States   >50K
#
# [265 rows x 14 columns]

# %%
data[(data['workclass'].isna() == True) & (data['class'] == ' <=50K')]
# Out:
#        age workclass      education  education-num       marital-status  \
# 4       18       NaN   Some-college             10        Never-married
# 6       29       NaN        HS-grad              9        Never-married
# 13      58       NaN        HS-grad              9   Married-civ-spouse
# 22      72       NaN        7th-8th              4             Divorced
# 35      65       NaN        HS-grad              9   Married-civ-spouse
# ...    ...       ...            ...            ...                  ...
# 48775   82       NaN        HS-grad              9        Never-married
# 48806   81       NaN      Assoc-voc             11             Divorced
# 48812   30       NaN      Bachelors             13        Never-married
# 48822   41       NaN        HS-grad              9            Separated
# 48823   72       NaN        HS-grad              9   Married-civ-spouse
#
#       occupation    relationship                 race      sex  capital-gain  \
# 4            NaN       Own-child                White   Female             0
# 6            NaN       Unmarried                Black     Male             0
# 13           NaN         Husband                White     Male             0
# 22           NaN   Not-in-family                White   Female             0
# 35           NaN         Husband                White     Male             0
# ...          ...             ...                  ...      ...           ...
# 48775        NaN   Not-in-family                White     Male             0
# 48806        NaN       Unmarried                White   Female             0
# 48812        NaN   Not-in-family   Asian-Pac-Islander   Female             0
# 48822        NaN   Not-in-family                Black   Female             0
# 48823        NaN         Husband                White     Male             0
#
#        capital-loss  hours-per-week  native-country   class
# 4                 0              30   United-States   <=50K
# 6                 0              40   United-States   <=50K
# 13                0              35   United-States   <=50K
# 22                0               6   United-States   <=50K
# 35                0              40   United-States   <=50K
# ...             ...             ...             ...     ...
# 48775             0               3   United-States   <=50K
# 48806             0               1             NaN   <=50K
# 48812             0              99   United-States   <=50K
# 48822             0              32   United-States   <=50K
# 48823             0              25   United-States   <=50K
#
# [2534 rows x 14 columns]

# %%
data[(data['occupation'].isna() == True) & (data['class'] == ' >50K')]
# Out:
#        age workclass      education  education-num       marital-status  \
# 89      41       NaN        Masters             14   Married-civ-spouse
# 182     28       NaN        HS-grad              9   Married-civ-spouse
# 274     53       NaN        HS-grad              9   Married-civ-spouse
# 505     38       NaN        HS-grad              9   Married-civ-spouse
# 781     62       NaN        HS-grad              9   Married-civ-spouse
# ...    ...       ...            ...            ...                  ...
# 48278   60       NaN   Some-college             10   Married-civ-spouse
# 48279   52       NaN           12th              8   Married-civ-spouse
# 48297   62       NaN        HS-grad              9   Married-civ-spouse
# 48811   35       NaN      Bachelors             13   Married-civ-spouse
# 48820   71       NaN      Doctorate             16   Married-civ-spouse
#
#       occupation relationship    race      sex  capital-gain  capital-loss  \
# 89           NaN         Wife   White   Female          7688             0
# 182          NaN    Own-child   White   Female             0             0
# 274          NaN      Husband   White     Male             0             0
# 505          NaN         Wife   White   Female             0          1887
# 781          NaN      Husband   White     Male          5178             0
# ...          ...          ...     ...      ...           ...           ...
# 48278        NaN      Husband   White     Male             0             0
# 48279        NaN         Wife   Black   Female             0             0
# 48297        NaN      Husband   White     Male             0             0
# 48811        NaN         Wife   White   Female             0             0
# 48820        NaN      Husband   White     Male             0             0
#
#        hours-per-week  native-country  class
# 89                 10   United-States   >50K
# 182                38   United-States   >50K
# 274                35   United-States   >50K
# 505                10   United-States   >50K
# 781                40   United-States   >50K
# ...               ...             ...    ...
# 48278              12   United-States   >50K
# 48279              40   United-States   >50K
# 48297              40   United-States   >50K
# 48811              55   United-States   >50K
# 48820              10   United-States   >50K
#
# [265 rows x 14 columns]

# %%
data['class'].value_counts()
# Out:
# class
#  <=50K    37155
#  >50K     11687
# Name: count, dtype: int64

# %%
data2 = data.copy()

# %%
data = data.dropna()

# %%
data['class'].value_counts()
# Out:
# class
#  <=50K    34014
#  >50K     11208
# Name: count, dtype: int64

# %%
11208/34014*100
# Out:
# 32.95113776680191

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45222 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45222 non-null  int64
#  1   workclass       45222 non-null  object
#  2   education       45222 non-null  object
#  3   education-num   45222 non-null  int64
#  4   marital-status  45222 non-null  object
#  5   occupation      45222 non-null  object
#  6   relationship    45222 non-null  object
#  7   race            45222 non-null  object
#  8   sex             45222 non-null  object
#  9   capital-gain    45222 non-null  int64
#  10  capital-loss    45222 non-null  int64
#  11  hours-per-week  45222 non-null  int64
#  12  native-country  45222 non-null  object
#  13  class           45222 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# # Age

# %%
def age_dist(age):
    if 10 <= age < 20:
        return '10s'
    elif 20 <= age < 30:
        return '20s'
    elif 30 <= age < 40:
        return '30s'
    elif 40 <= age < 50:
        return '40s'
    elif 50 <= age < 60:
        return '50s'
    elif 60 <= age < 70:
        return '60s'
    elif 70 <= age < 80:
        return '70s'
    elif 80 <= age < 90:
        return '80s'
    elif 90 <= age < 100:
        return '90s'

# %%
data['age'] = data['age'].apply(age_dist)

# %%
data.head(2)
# Out:
#    age workclass education  education-num       marital-status  \
# 0  20s   Private      11th              7        Never-married
# 1  30s   Private   HS-grad              9   Married-civ-spouse
#
#            occupation relationship    race    sex  capital-gain  capital-loss  \
# 0   Machine-op-inspct    Own-child   Black   Male             0             0
# 1     Farming-fishing      Husband   White   Male             0             0
#
#    hours-per-week  native-country   class
# 0              40   United-States   <=50K
# 1              50   United-States   <=50K

# %%
data['age'].value_counts(sort=False)
# Out:
# age
# 20s    10993
# 30s    12362
# 40s    10305
# 60s     2514
# 50s     6264
# 10s     2052
# 70s      589
# 80s       97
# 90s       46
# Name: count, dtype: int64

# %%
data.loc[data['age'] == '90s']
# Out:
#        age          workclass      education  education-num  \
# 899    90s            Private     Assoc-acdm             12
# 3496   90s   Self-emp-not-inc    Prof-school             15
# 6976   90s            Private        HS-grad              9
# 7414   90s            Private     Assoc-acdm             12
# 7419   90s   Self-emp-not-inc    Prof-school             15
# 8427   90s        Federal-gov        Masters             14
# 8982   90s            Private        HS-grad              9
# 10735  90s          Local-gov        HS-grad              9
# 12446  90s            Private   Some-college             10
# 13958  90s            Private   Some-college             10
# 15088  90s            Private        HS-grad              9
# 16503  90s            Private        HS-grad              9
# 17321  90s            Private        HS-grad              9
# 18216  90s            Private      Bachelors             13
# 18584  90s            Private   Some-college             10
# 19172  90s            Private   Some-college             10
# 20351  90s            Private           11th              7
# 21385  90s            Private   Some-college             10
# 21553  90s            Private            9th              5
# 21651  90s          Local-gov        Masters             14
# 21687  90s            Private        Masters             14
# 22513  90s   Self-emp-not-inc      Bachelors             13
# 22905  90s            Private           11th              7
# 25087  90s            Private    Prof-school             15
# 25254  90s            Private      Bachelors             13
# 26491  90s   Self-emp-not-inc   Some-college             10
# 26826  90s            Private        HS-grad              9
# 27793  90s            Private        HS-grad              9
# 28277  90s            Private      Bachelors             13
# 29256  90s            Private           10th              6
# 30440  90s          Local-gov     Assoc-acdm             12
# 31637  90s            Private        HS-grad              9
# 32173  90s            Private      Bachelors             13
# 34694  90s            Private      Bachelors             13
# 35006  90s          Local-gov        HS-grad              9
# 35113  90s            Private        Masters             14
# 35493  90s            Private   Some-college             10
# 35770  90s            Private        HS-grad              9
# 36028  90s            Private        7th-8th              4
# 36891  90s            Private        Masters             14
# 38501  90s            Private      Bachelors             13
# 40324  90s   Self-emp-not-inc        HS-grad              9
# 44744  90s        Federal-gov        HS-grad              9
# 47311  90s            Private        HS-grad              9
# 48558  90s            Private        HS-grad              9
# 48648  90s          Local-gov        7th-8th              4
#
#             marital-status          occupation    relationship  \
# 899     Married-civ-spouse               Sales         Husband
# 3496               Widowed      Prof-specialty   Not-in-family
# 6976    Married-civ-spouse    Transport-moving         Husband
# 7414         Never-married     Exec-managerial   Not-in-family
# 7419    Married-civ-spouse      Prof-specialty         Husband
# 8427              Divorced      Prof-specialty   Not-in-family
# 8982    Married-civ-spouse        Craft-repair         Husband
# 10735        Never-married        Craft-repair       Own-child
# 12446        Never-married        Adm-clerical       Own-child
# 13958        Never-married       Other-service       Own-child
# 15088        Never-married        Adm-clerical   Not-in-family
# 16503        Never-married       Other-service   Not-in-family
# 17321        Never-married       Other-service   Not-in-family
# 18216   Married-civ-spouse     Exec-managerial         Husband
# 18584        Never-married       Other-service   Not-in-family
# 19172            Separated        Adm-clerical       Own-child
# 20351        Never-married   Handlers-cleaners       Own-child
# 21385        Never-married       Other-service   Not-in-family
# 21553        Never-married        Adm-clerical   Not-in-family
# 21651   Married-civ-spouse     Exec-managerial         Husband
# 21687        Never-married     Exec-managerial   Not-in-family
# 22513   Married-civ-spouse      Prof-specialty         Husband
# 22905   Married-civ-spouse        Craft-repair         Husband
# 25087   Married-civ-spouse      Prof-specialty         Husband
# 25254   Married-civ-spouse               Sales         Husband
# 26491   Married-civ-spouse     Farming-fishing         Husband
# 26826   Married-civ-spouse        Craft-repair         Husband
# 27793        Never-married       Other-service       Own-child
# 28277        Never-married     Exec-managerial   Not-in-family
# 29256   Married-civ-spouse     Exec-managerial         Husband
# 30440   Married-civ-spouse        Adm-clerical         Husband
# 31637              Widowed    Transport-moving       Unmarried
# 32173   Married-civ-spouse     Exec-managerial            Wife
# 34694        Never-married      Prof-specialty       Own-child
# 35006   Married-civ-spouse       Other-service         Husband
# 35113        Never-married     Exec-managerial       Own-child
# 35493             Divorced               Sales       Unmarried
# 35770   Married-civ-spouse   Machine-op-inspct         Husband
# 36028   Married-civ-spouse   Machine-op-inspct         Husband
# 36891   Married-civ-spouse      Prof-specialty            Wife
# 38501        Never-married      Prof-specialty   Not-in-family
# 40324        Never-married     Exec-managerial   Not-in-family
# 44744   Married-civ-spouse        Craft-repair         Husband
# 47311   Married-civ-spouse   Machine-op-inspct         Husband
# 48558              Widowed        Adm-clerical       Unmarried
# 48648   Married-civ-spouse     Protective-serv         Husband
#
#                       race      sex  capital-gain  capital-loss  \
#
# %%
data.groupby('age')['class'].value_counts(sort=False)
# Out:
# age  class
# 10s   <=50K     2050
#       >50K         2
# 20s   <=50K    10274
#       >50K       719
# 30s   <=50K     8996
#       >50K      3366
# 40s   <=50K     6425
#       >50K      3880
# 50s   <=50K     3855
#       >50K      2409
# 60s   <=50K     1828
#       >50K       686
# 70s   <=50K      469
#       >50K       120
# 80s   <=50K       83
#       >50K        14
# 90s   <=50K       34
#       >50K        12
# Name: count, dtype: int64

# %%
data['age'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ## workclass

# %%
data['workclass'].value_counts()
# Out:
# workclass
#  Private             33307
#  Self-emp-not-inc     3796
#  Local-gov            3100
#  State-gov            1946
#  Self-emp-inc         1646
#  Federal-gov          1406
#  Without-pay            21
# Name: count, dtype: int64

# %%
data = data.apply(lambda x: x.str.strip().replace(" ","") if x.dtype == 'O' else x)

# %%
workclass_clsss = data.groupby('workclass')['class'].value_counts(sort=False)

# %%
data['class'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
def c_ratio(x):
    for idx, item in zip(x.index, x):
        if idx[1] == '<=50K':
            under_50 = item
        else:
            upper_50 = item
            class_ratio = upper_50/(upper_50+under_50) * 100
            print(idx, f'{class_ratio:.2f}%')

# %%
c_ratio(workclass_clsss)
# Out:
# ('Federal-gov', '>50K') 39.05%
# ('Local-gov', '>50K') 29.52%
# ('Private', '>50K') 21.77%
# ('Self-emp-inc', '>50K') 55.41%
# ('Self-emp-not-inc', '>50K') 27.90%
# ('State-gov', '>50K') 26.72%
# ('Without-pay', '>50K') 9.52%

# %% [markdown]
# * 중앙정부에서 일할 경우 5만불 이상일 가능성이 높고, 자영업자의 경우 55%에 달함

# %% [markdown]
# ### education

# %%
data['education'].value_counts()
# Out:
# education
# HS-grad         14783
# Some-college     9899
# Bachelors        7570
# Masters          2514
# Assoc-voc        1959
# 11th             1619
# Assoc-acdm       1507
# 10th             1223
# 7th-8th           823
# Prof-school       785
# 9th               676
# 12th              577
# Doctorate         544
# 5th-6th           449
# 1st-4th           222
# Preschool          72
# Name: count, dtype: int64

# %%
education_class = data.groupby('education')['class'].value_counts(sort=False)
c_ratio(education_class)
# Out:
# ('10th', '>50K') 6.70%
# ('11th', '>50K') 5.50%
# ('12th', '>50K') 7.45%
# ('1st-4th', '>50K') 3.60%
# ('5th-6th', '>50K') 4.90%
# ('7th-8th', '>50K') 6.68%
# ('9th', '>50K') 5.62%
# ('Assoc-acdm', '>50K') 26.41%
# ('Assoc-voc', '>50K') 25.73%
# ('Bachelors', '>50K') 41.98%
# ('Doctorate', '>50K') 73.35%
# ('HS-grad', '>50K') 16.34%
# ('Masters', '>50K') 55.41%
# ('Preschool', '>50K') 1.39%
# ('Prof-school', '>50K') 75.41%
# ('Some-college', '>50K') 20.10%

# %% [markdown]
# * 학력이 높을 수록 연봉 5만 이상자가 많다.

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %% [markdown]
# ## education-num

# %%
data['education-num'].value_counts()
# Out:
# education-num
# 9     14783
# 10     9899
# 13     7570
# 14     2514
# 11     1959
# 7      1619
# 12     1507
# 6      1223
# 4       823
# 15      785
# 5       676
# 8       577
# 16      544
# 3       449
# 2       222
# 1        72
# Name: count, dtype: int64

# %%
edu_num = data.groupby('education-num')['class'].value_counts(sort=False)
c_ratio(edu_num)
# Out:
# (1, '>50K') 1.39%
# (2, '>50K') 3.60%
# (3, '>50K') 4.90%
# (4, '>50K') 6.68%
# (5, '>50K') 5.62%
# (6, '>50K') 6.70%
# (7, '>50K') 5.50%
# (8, '>50K') 7.45%
# (9, '>50K') 16.34%
# (10, '>50K') 20.10%
# (11, '>50K') 25.73%
# (12, '>50K') 26.41%
# (13, '>50K') 41.98%
# (14, '>50K') 55.41%
# (15, '>50K') 75.41%
# (16, '>50K') 73.35%

# %% [markdown]
# * 교육기간이 길수록 연봉이 높다

# %% [markdown]
# ## marital-status

# %%
data['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Separated',
#        'Divorced', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
data['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       21055
# Never-married            14598
# Divorced                  6297
# Separated                 1411
# Widowed                   1277
# Married-spouse-absent      552
# Married-AF-spouse           32
# Name: count, dtype: int64

# %%
mari_stat = data.groupby('marital-status')['class'].value_counts(sort=False)
c_ratio(mari_stat)
# Out:
# ('Divorced', '>50K') 10.40%
# ('Married-AF-spouse', '>50K') 43.75%
# ('Married-civ-spouse', '>50K') 45.42%
# ('Married-spouse-absent', '>50K') 9.78%
# ('Never-married', '>50K') 4.80%
# ('Separated', '>50K') 7.02%
# ('Widowed', '>50K') 9.48%

# %% [markdown]
# * 결혼을 했을 경우 소득이 높다

# %% [markdown]
# ## occupation

# %%
data['occupation'].value_counts()
# Out:
# occupation
# Craft-repair         6020
# Prof-specialty       6008
# Exec-managerial      5984
# Adm-clerical         5540
# Sales                5408
# Other-service        4808
# Machine-op-inspct    2970
# Transport-moving     2316
# Handlers-cleaners    2046
# Farming-fishing      1480
# Tech-support         1420
# Protective-serv       976
# Priv-house-serv       232
# Armed-Forces           14
# Name: count, dtype: int64

# %%
occu = data.groupby('occupation')['class'].value_counts(sort=False)
c_ratio(occu)
# Out:
# ('Adm-clerical', '>50K') 13.65%
# ('Armed-Forces', '>50K') 28.57%
# ('Craft-repair', '>50K') 22.51%
# ('Exec-managerial', '>50K') 47.91%
# ('Farming-fishing', '>50K') 11.62%
# ('Handlers-cleaners', '>50K') 6.60%
# ('Machine-op-inspct', '>50K') 12.29%
# ('Other-service', '>50K') 4.08%
# ('Priv-house-serv', '>50K') 1.29%
# ('Prof-specialty', '>50K') 45.01%
# ('Protective-serv', '>50K') 31.45%
# ('Sales', '>50K') 26.90%
# ('Tech-support', '>50K') 28.94%
# ('Transport-moving', '>50K') 20.64%

# %% [markdown]
# * Exec-managerial, Prof-specialty 인경우 소득이 높음

# %% [markdown]
# ## relationship

# %%
data['relationship'].value_counts()
# Out:
# relationship
# Husband           18666
# Not-in-family     11702
# Own-child          6626
# Unmarried          4788
# Wife               2091
# Other-relative     1349
# Name: count, dtype: int64

# %%
relation = data.groupby('relationship')['class'].value_counts(sort=False)
c_ratio(relation)
# Out:
# ('Husband', '>50K') 45.57%
# ('Not-in-family', '>50K') 10.49%
# ('Other-relative', '>50K') 3.71%
# ('Own-child', '>50K') 1.58%
# ('Unmarried', '>50K') 6.31%
# ('Wife', '>50K') 48.59%

# %% [markdown]
# * 남편과 아내인 경우 소득이 높다

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %% [markdown]
# ## race

# %%
data['race'].value_counts()
# Out:
# race
# White                 38903
# Black                  4228
# Asian-Pac-Islander     1303
# Amer-Indian-Eskimo      435
# Other                   353
# Name: count, dtype: int64

# %%
race = data.groupby('race')['class'].value_counts(sort=False)
c_ratio(race)
# Out:
# ('Amer-Indian-Eskimo', '>50K') 12.18%
# ('Asian-Pac-Islander', '>50K') 28.32%
# ('Black', '>50K') 12.63%
# ('Other', '>50K') 12.75%
# ('White', '>50K') 26.24%

# %% [markdown]
# * 아시아인이거나 백인인 경우 소득이 높은 편

# %% [markdown]
# ## sex

# %%
data['sex'].value_counts()
# Out:
# sex
# Male      30527
# Female    14695
# Name: count, dtype: int64

# %%
sex = data.groupby('sex')['class'].value_counts(sort=False)
c_ratio(sex)
# Out:
# ('Female', '>50K') 11.36%
# ('Male', '>50K') 31.25%

# %%
data['capital-gain'].describe()
# Out:
# count    45222.000000
# mean      1101.430344
# std       7506.430084
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital-gain, dtype: float64

# %%
data['capital-gain'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['capital-gain'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['capital-gain'] = data['capital-gain'].apply(lambda x: 1 if x > 0 else 0)

# %%
data['capital-loss'] = data['capital-loss'].apply(lambda x: 1 if x > 0 else 0)

# %%
data.head(2)
# Out:
#    age workclass education  education-num      marital-status  \
# 0  20s   Private      11th              7       Never-married
# 1  30s   Private   HS-grad              9  Married-civ-spouse
#
#           occupation relationship   race   sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black  Male             0             0
# 1    Farming-fishing      Husband  White  Male             0             0
#
#    hours-per-week native-country  class
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K

# %%
data['capital-gain'].value_counts()
# Out:
# capital-gain
# 0    41432
# 1     3790
# Name: count, dtype: int64

# %%
data['capital-loss'].value_counts()
# Out:
# capital-loss
# 0    43082
# 1     2140
# Name: count, dtype: int64

# %%
cgain = data.groupby('capital-gain')['class'].value_counts(sort=False)
c_ratio(cgain)
# Out:
# (0, '>50K') 21.32%
# (1, '>50K') 62.66%

# %%
closs = data.groupby('capital-loss')['class'].value_counts(sort=False)
c_ratio(closs)
# Out:
# (0, '>50K') 23.47%
# (1, '>50K') 51.31%

# %% [markdown]
# ## hours-per-week

# %%
data['hours-per-week'].value_counts()
# Out:
# hours-per-week
# 40    21358
# 50     4094
# 45     2602
# 60     2085
# 35     1776
#       ...
# 79        1
# 69        1
# 87        1
# 94        1
# 82        1
# Name: count, Length: 96, dtype: int64

# %%
data['hours-per-week'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['hours-per-week'].describe()
# Out:
# count    45222.000000
# mean        40.938017
# std         12.007508
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
# 정상 범위
nor_max = 45 + ((45-40) *1.5)
nor_min = 40 - ((45-40) *1.5)
print(nor_max)
print(nor_min)
# Out:
# 52.5
# 32.5

# %%
def work_hour(x):
    if x > 52.5:
        return 'work_more'
    elif x < 32.5:
        return 'work_less'
    else:
        return 'work_normal'

# %%
data['hours-per-week'] = data['hours-per-week'].apply(work_hour)

# %%
hpw = data.groupby('hours-per-week')['class'].value_counts(sort=False)
c_ratio(hpw)
# Out:
# ('work_less', '>50K') 6.82%
# ('work_more', '>50K') 41.80%
# ('work_normal', '>50K') 25.97%

# %% [markdown]
# * 일을 많이 하는 사람이 연봉이 높을 가능성이 높다.

# %% [markdown]
# ## native-country

# %%
data['native-country'].value_counts()
# Out:
# native-country
# United-States                 41292
# Mexico                          903
# Philippines                     283
# Germany                         193
# Puerto-Rico                     175
# Canada                          163
# El-Salvador                     147
# India                           147
# Cuba                            133
# England                         119
# China                           113
# Jamaica                         103
# South                           101
# Italy                           100
# Dominican-Republic               97
# Japan                            89
# Guatemala                        86
# Vietnam                          83
# Columbia                         82
# Poland                           81
# Haiti                            69
# Portugal                         62
# Iran                             56
# Taiwan                           55
# Greece                           49
# Nicaragua                        48
# Peru                             45
# Ecuador                          43
# France                           36
# Ireland                          36
# Thailand                         29
# Hong                             28
# Cambodia                         26
# Trinadad&Tobago                  26
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       22
# Laos                             21
# Scotland                         20
# Honduras                         19
# Hungary                          18
# Holand-Netherlands                1
# Name: count, dtype: int64

# %%
n_country = data.groupby('native-country')['class'].value_counts(sort=False)
c_ratio(n_country)
# Out:
# ('Cambodia', '>50K') 34.62%
# ('Canada', '>50K') 36.81%
# ('China', '>50K') 31.86%
# ('Columbia', '>50K') 4.88%
# ('Cuba', '>50K') 25.56%
# ('Dominican-Republic', '>50K') 5.15%
# ('Ecuador', '>50K') 13.95%
# ('El-Salvador', '>50K') 7.48%
# ('England', '>50K') 39.50%
# ('France', '>50K') 44.44%
# ('Germany', '>50K') 30.05%
# ('Greece', '>50K') 36.73%
# ('Guatemala', '>50K') 3.49%
# ('Haiti', '>50K') 13.04%
# ('Honduras', '>50K') 10.53%
# ('Hong', '>50K') 28.57%
# ('Hungary', '>50K') 33.33%
# ('India', '>50K') 42.18%
# ('Iran', '>50K') 39.29%
# ('Ireland', '>50K') 27.78%
# ('Italy', '>50K') 33.00%
# ('Jamaica', '>50K') 13.59%
# ('Japan', '>50K') 34.83%
# ('Laos', '>50K') 9.52%
# ('Mexico', '>50K') 5.20%
# ('Nicaragua', '>50K') 6.25%
# ('Outlying-US(Guam-USVI-etc)', '>50K') 4.55%
# ('Peru', '>50K') 8.89%
# ('Philippines', '>50K') 29.68%
# ('Poland', '>50K') 19.75%
# ('Portugal', '>50K') 19.35%
# ('Puerto-Rico', '>50K') 11.43%
# ('Scotland', '>50K') 10.00%
# ('South', '>50K') 17.82%
# ('Taiwan', '>50K') 45.45%
# ('Thailand', '>50K') 17.24%
# ('Trinadad&Tobago', '>50K') 7.69%
# ('United-States', '>50K') 25.30%
# ('Vietnam', '>50K') 8.43%
# ('Yugoslavia', '>50K') 34.78%

# %%
data.head(2)
# Out:
#    age workclass education  education-num      marital-status  \
# 0  20s   Private      11th              7       Never-married
# 1  30s   Private   HS-grad              9  Married-civ-spouse
#
#           occupation relationship   race   sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black  Male             0             0
# 1    Farming-fishing      Husband  White  Male             0             0
#
#   hours-per-week native-country  class
# 0    work_normal  United-States  <=50K
# 1    work_normal  United-States  <=50K

# %%
data = data.drop(["education", "capital-gain", "capital-loss"], axis=1)

# %% [markdown]
# # 더미변수화

# %%
data.head(2)
# Out:
#    age workclass  education-num      marital-status         occupation  \
# 0  20s   Private              7       Never-married  Machine-op-inspct
# 1  30s   Private              9  Married-civ-spouse    Farming-fishing
#
#   relationship   race   sex hours-per-week native-country  class
# 0    Own-child  Black  Male    work_normal  United-States  <=50K
# 1      Husband  White  Male    work_normal  United-States  <=50K

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data.head()
# Out:
#    education-num  age_20s  age_30s  age_40s  age_50s  age_60s  age_70s  \
# 0              7     True    False    False    False    False    False
# 1              9    False     True    False    False    False    False
# 2             12     True    False    False    False    False    False
# 3             10    False    False     True    False    False    False
# 5              6    False     True    False    False    False    False
#
#    age_80s  age_90s  workclass_Local-gov  ...  native-country_Puerto-Rico  \
# 0    False    False                False  ...                       False
# 1    False    False                False  ...                       False
# 2    False    False                 True  ...                       False
# 3    False    False                False  ...                       False
# 5    False    False                False  ...                       False
#
#    native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                    False                 False                  False
# 1                    False                 False                  False
# 2                    False                 False                  False
# 3                    False                 False                  False
# 5                    False                 False                  False
#
#    native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                    False                           False
# 1                    False                           False
# 2                    False                           False
# 3                    False                           False
# 5                    False                           False
#
#    native-country_United-States  native-country_Vietnam  \
# 0                          True                   False
# 1                          True                   False
# 2                          True                   False
# 3                          True                   False
# 5                          True                   False
#
#    native-country_Yugoslavia  class_>50K
# 0                      False       False
# 1                      False       False
# 2                      False        True
# 3                      False        True
# 5                      False       False
#
# [5 rows x 87 columns]

# %%
X = data.drop("class_>50K", axis=1)
y = data['class_>50K']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45222 entries, 0 to 48841
# Data columns (total 86 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   education-num                              45222 non-null  int64
#  1   age_20s                                    45222 non-null  bool
#  2   age_30s                                    45222 non-null  bool
#  3   age_40s                                    45222 non-null  bool
#  4   age_50s                                    45222 non-null  bool
#  5   age_60s                                    45222 non-null  bool
#  6   age_70s                                    45222 non-null  bool
#  7   age_80s                                    45222 non-null  bool
#  8   age_90s                                    45222 non-null  bool
#  9   workclass_Local-gov                        45222 non-null  bool
#  10  workclass_Private                          45222 non-null  bool
#  11  workclass_Self-emp-inc                     45222 non-null  bool
#  12  workclass_Self-emp-not-inc                 45222 non-null  bool
#  13  workclass_State-gov                        45222 non-null  bool
#  14  workclass_Without-pay                      45222 non-null  bool
#  15  marital-status_Married-AF-spouse           45222 non-null  bool
#  16  marital-status_Married-civ-spouse          45222 non-null  bool
#  17  marital-status_Married-spouse-absent       45222 non-null  bool
#  18  marital-status_Never-married               45222 non-null  bool
#  19  marital-status_Separated                   45222 non-null  bool
#  20  marital-status_Widowed                     45222 non-null  bool
#  21  occupation_Armed-Forces                    45222 non-null  bool
#  22  occupation_Craft-repair                    45222 non-null  bool
#  23  occupation_Exec-managerial                 45222 non-null  bool
#  24  occupation_Farming-fishing                 45222 non-null  bool
#  25  occupation_Handlers-cleaners               45222 non-null  bool
#  26  occupation_Machine-op-inspct               45222 non-null  bool
#  27  occupation_Other-service                   45222 non-null  bool
#  28  occupation_Priv-house-serv                 45222 non-null  bool
#  29  occupation_Prof-specialty                  45222 non-null  bool
#  30  occupation_Protective-serv                 45222 non-null  bool
#  31  occupation_Sales                           45222 non-null  bool
#  32  occupation_Tech-support                    45222 non-null  bool
#  33  occupation_Transport-moving                45222 non-null  bool
#  34  relationship_Not-in-family                 45222 non-null  bool
#  35  relationship_Other-relative                45222 non-null  bool
#  36  relationship_Own-child                     45222 non-null  bool
#  37  relationship_Unmarried                     45222 non-null  bool
#  38  relationship_Wife                          45222 non-null  bool
#  39  race_Asian-Pac-Islander                    45222 non-null  bool
#  40  race_Black                                 45222 non-null  bool
#  41  race_Other                                 45222 non-null  bool
#  42  race_White                                 45222 non-null  bool
#  43  sex_Male                                   45222 non-null  bool
#  44  hours-per-week_work_more                   45222 non-null  bool
#  45  hours-per-week_work_normal                 45222 non-null  bool
#  46  native-country_Canada                      45222 non-null  bool
#  47  native-country_China                       45222 non-null  bool
#  48  native-country_Columbia                    45222 non-null  bool
#  49  native-country_Cuba                        45222 non-null  bool
#  50  native-country_Dominican-Republic          45222 non-null  bool
#  51  native-country_Ecuador                     45222 non-null  bool
#  52  native-country_El-Salvador                 45222 non-null  bool
#  53  native-country_England                     45222 non-null  bool
#  54  native-country_France                      45222 non-null  bool
#  55  native-country_Germany                     45222 non-null  bool
#  56  native-country_Greece                      45222 non-null  bool
#  57  native-country_Guatemala                   45222 non-null  bool
#  58  native-country_Haiti                       45222 non-null  bool
#  59  native-country_Holand-Netherlands          45222 non-null  bool
#  60  native-country_Honduras                    45222 non-null  bool
#  61  native-country_Hong                        45222 non-null  bool
#  62  native-country_Hungary                     45222 non-null  bool
#  63  native-country_India                       45222 non-null  bool
#  64  native-country_Iran                        45222 non-null  bool
#  65  native-country_Ireland                     45222 non-null  bool
#  66  native-country_Italy                       45222 non-null  bool
#  67  native-country_Jamaica                     45222 non-null  bool
#  68  native-country_Japan                       45222 non-null  bool
#  69  native-country_Laos                        45222 non-null  bool
#  70  native-country_Mexico                      45222 non-null  bool
#  71  native-country_Nicaragua                   45222 non-null  bool
#  72  native-country_Outlying-US(Guam-USVI-etc)  45222 non-null  bool
#  73  native-country_Peru                        45222 non-null  bool
#  74  native-country_Philippines                 45222 non-null  bool
#  75  native-country_Poland                      45222 non-null  bool
#  76  native-country_Portugal                    45222 non-null  bool
#  77  native-country_Puerto-Rico                 45222 non-null  bool
#  78  native-country_Scotland                    45222 non-null  bool
#  79  native-country_South                       45222 non-null  bool
#  80  native-country_Taiwan                      45222 non-null  bool
#  81  native-country_Thailand                    45222 non-null  bool
#  82  native-country_Trinadad&Tobago             45222 non-null  bool
#  83  native-country_United-States               45222 non-null  bool
#  84  native-country_Vietnam                     45222 non-null  bool
#  85  native-country_Yugoslavia                  45222 non-null  bool
# dtypes: bool(85), int64(1)
# memory usage: 5.4 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state = 10)

# %% [markdown]
# # 앙상블 분석
# ### 예측력을 높이기 위해서 여러 번의 데이터 분할을 통해 구축된 다수의 모형을 결합해서 새로운 모형을 만드는 방법
# #### 앙상블(Ensemble) 분석의 종류
# * 배깅(Bsgging)
# * 부스팅(Boosting)
#   * ADABoost(에이다 부스트)
#   * XGBoost(XG 부스트)
#   * Gradient Boost(그래디언트 부스트)
#   * LightGBM (라이트 GBM)
# * 랜덤배깅(Random Bagging)
#   * Random Forest(랜덤 포레스트)

# %% [markdown]
# ### 배깅(Bsgging)
# * 여러 개의 부트스트랩을 생성해서 각각을 분류기에 넣고 분석한 결과는 집계하는 알고리즘
# * 여러 개의 분류기에 의한 결과를 놓고 다수결에 의하여 최종 결과값을 선정하는 보팅(voting)으로 결정

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
bcf = BaggingClassifier(n_estimators=1000, n_jobs=-1, random_state = 10)
bcf.fit(X_train, y_train)
pred_bcf = bcf.predict(X_test)
print(accuracy_score(y_test, pred_bcf))
print(classification_report(y_test, pred_bcf))
# Out:
# 0.8135549495098401
#               precision    recall  f1-score   support
#
#        False       0.86      0.90      0.88     20411
#         True       0.64      0.56      0.60      6723
#
#     accuracy                           0.81     27134
#    macro avg       0.75      0.73      0.74     27134
# weighted avg       0.81      0.81      0.81     27134

# %% [markdown]
# ## 부스팅

# %% [markdown]
# ### 1. 에이다 부스팅 ADABoosting
# * 오류에 가중치를 부여하면서 부스팅을 수행하는 대표적인 알고리즘
# * 요류를 최소화 하는 방향성을 가지고 반복적으로 가중치를 업데이트 해서 성능 향상
# * DecisionTreeClassifier(max_depth=1)을 사용하는 아주 약한 학습기
# * 순차적으로 학습해야 하므로 멀티코어 사용불가, 분석시간 오래걸림
# * 하이퍼파라미터
#   * n_estimators: int, default=50
#   * learning_rate: float, default=1.0
#   * algorithm: {'SAMME', 'SAMMER.R'}, default='SAMMER.R'

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(n_estimators = 1000, random_state=10)
ada.fit(X_train, y_train)
pred_ada = ada.predict(X_test)
print(accuracy_score(y_test, pred_ada))
print(classification_report(y_test, pred_ada))
# Out:
# 0.8335667428318715
#               precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89     20411
#         True       0.70      0.58      0.63      6723
#
#     accuracy                           0.83     27134
#    macro avg       0.78      0.75      0.76     27134
# weighted avg       0.83      0.83      0.83     27134

# %% [markdown]
# ### 2. 그래디언트부스팅 GradientTreeBoosting
# * 이전 트리의 오차를 보완하는 방식으로 순차적 트리 생성
# * 무작위성은 없지만 강력한 사전 가지치지가 사용 됨
# * 오류에 가중치를 부여하면서 부스팅을 수행하는 점에서는 동일하나 가중치 업데이트를 경사하강법을 이요해 한다는 점이 다름
# * 약한 학습기의 순차적인 예측 오류 보정을 통해서 학습을 수행하므로 멀티코어 병렬처리가 안됨 => 분석 시간이 오래 걸림
# * 하이퍼파라미터
#   * loss: 경사 하강법에 사용할 비용 함수
#   * learning_rate: 학습율 0~1 사이의 값 작은 값일 수록 예측성능이 좋아질 수 있으나 시간이 오래 걸리고 너무 작으면 지역해에 빠질 수 있다.
#   * n_estimators: 기본 100, 약학습기의 숫자가 많을 수록 예측 성능 향상되나 과적합 우려가 있음.
#   * learning_rate를 작게하고 n_estimators를 크게하면 한계점까지 예측 성능이 좋아질 수 있음
#   * max_depth: defalut= 3 트리의 복잡도가 낮아지도록 5를 넘지 않게 세팅

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=1000, random_state=10)
gbc.fit(X_train, y_train)
pred_gbc = gbc.predict(X_test)
print(accuracy_score(y_test, pred_gbc))
print(classification_report(y_test, pred_gbc))
# Out:
# 0.8352620328738851
#               precision    recall  f1-score   support
#
#        False       0.87      0.91      0.89     20411
#         True       0.69      0.60      0.64      6723
#
#     accuracy                           0.84     27134
#    macro avg       0.78      0.76      0.77     27134
# weighted avg       0.83      0.84      0.83     27134

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(learning_rate=0.01, n_estimators=10000, random_state=10)
gbc.fit(X_train, y_train)
pred_gbc = gbc.predict(X_test)
print(accuracy_score(y_test, pred_gbc))
print(classification_report(y_test, pred_gbc))
# Out:
# 0.8360359696321957
#               precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89     20411
#         True       0.70      0.59      0.64      6723
#
#     accuracy                           0.84     27134
#    macro avg       0.79      0.75      0.77     27134
# weighted avg       0.83      0.84      0.83     27134

# %% [markdown]
# ### 히스토그램 그래디언트 부스팅(HistGradientBoostingClassifier)
# * 데이터가 10만개 이상일 경우 사용
# * 그래디언트 부스팅 보다 속도가 빠름

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
hbc = HistGradientBoostingClassifier(random_state=10)
hbc.fit(X_train, y_train)
pred_hbc = hbc.predict(X_test)
print(accuracy_score(y_test, pred_hbc))
print(classification_report(y_test, pred_hbc))
# Out:
# 0.8360359696321957
#               precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89     20411
#         True       0.70      0.59      0.64      6723
#
#     accuracy                           0.84     27134
#    macro avg       0.79      0.75      0.77     27134
# weighted avg       0.83      0.84      0.83     27134

# %% [markdown]
# ### XGBoost 현재 가장 우수한 알고리즘 중 하나
# * 그래디언트 부스팅의 느린 속도 및 과적합 문제를 해결
# * 멀티 코어 분석 지원
# * 자체 과적합 규제 기능
# * 더 이상 긍정적인 영향이 없는 가지에 대한 가지치기 기능
# * 교차검증 기능 자체 내장, 조기 중단 가능
# * 결측값 자체 처리
# * 주요 하이퍼파라미터
#   * learning_rate: 작게
#   * n_estimators: 크게
# * early stopping관련 옵션
#   * early_stopping_rounds=100
#   * eval_metric='logloss'
#   * eval_set=[(X_test, y_test)]
#   * verbose = True

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators= 1000, n_jobs=-1, learning_rate=0.01, random_state=10)
xgb.fit(X_train, y_train)
pred_xgb = xgb.predict(X_test)
print(accuracy_score(y_test, pred_xgb))
print(classification_report(y_test, pred_xgb))
# Out:
# 0.8369573229158989
#               precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89     20411
#         True       0.71      0.59      0.64      6723
#
#     accuracy                           0.84     27134
#    macro avg       0.79      0.75      0.77     27134
# weighted avg       0.83      0.84      0.83     27134

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators= 10000, n_jobs=-1, learning_rate=0.01, random_state=10)
xgb.fit(X_train, y_train, early_stopping_rounds = 100, eval_metric='logloss', eval_set=[(X_test, y_test)])
pred_xgb = xgb.predict(X_test)
print(accuracy_score(y_test, pred_xgb))
print(classification_report(y_test, pred_xgb))
# Out:
# C:\Users\hi\anaconda3\envs\testenv\lib\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\hi\anaconda3\envs\testenv\lib\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.55750
# [1]	validation_0-logloss:0.55422
# [2]	validation_0-logloss:0.55102
# [3]	validation_0-logloss:0.54789
# [4]	validation_0-logloss:0.54483
# [5]	validation_0-logloss:0.54184
# [6]	validation_0-logloss:0.53893
# [7]	validation_0-logloss:0.53607
# [8]	validation_0-logloss:0.53327
# [9]	validation_0-logloss:0.53053
# [10]	validation_0-logloss:0.52784
# [11]	validation_0-logloss:0.52522
# [12]	validation_0-logloss:0.52264
# [13]	validation_0-logloss:0.52012
# [14]	validation_0-logloss:0.51765
# [15]	validation_0-logloss:0.51523
# [16]	validation_0-logloss:0.51285
# [17]	validation_0-logloss:0.51053
# [18]	validation_0-logloss:0.50825
# [19]	validation_0-logloss:0.50602
# [20]	validation_0-logloss:0.50382
# [21]	validation_0-logloss:0.50168
# [22]	validation_0-logloss:0.49957
# [23]	validation_0-logloss:0.49749
# [24]	validation_0-logloss:0.49545
# [25]	validation_0-logloss:0.49347
# [26]	validation_0-logloss:0.49150
# [27]	validation_0-logloss:0.48958
# [28]	validation_0-logloss:0.48769
# [29]	validation_0-logloss:0.48585
# [30]	validation_0-logloss:0.48402
# [31]	validation_0-logloss:0.48223
# [32]	validation_0-logloss:0.48048
# [33]	validation_0-logloss:0.47874
# [34]	validation_0-logloss:0.47703
# [35]	validation_0-logloss:0.47538
# [36]	validation_0-logloss:0.47372
# [37]	validation_0-logloss:0.47210
# [38]	validation_0-logloss:0.47053
# [39]	validation_0-logloss:0.46896
# [40]	validation_0-logloss:0.46741
# [41]	validation_0-logloss:0.46591
# [42]	validation_0-logloss:0.46444
# [43]	validation_0-logloss:0.46295
# [44]	validation_0-logloss:0.46150
# [45]	validation_0-logloss:0.46011
# [46]	validation_0-logloss:0.45870
# [47]	validation_0-logloss:0.45731
# [48]	validation_0-logloss:0.45596
# [49]	validation_0-logloss:0.45465
# [50]	validation_0-logloss:0.45333
# [51]	validation_0-logloss:0.45204
# [533]	validation_0-logloss:0.35638
# [534]	validation_0-logloss:0.35636
# [535]	validation_0-logloss:0.35636
# [536]	validation_0-logloss:0.35633
# [537]	validation_0-logloss:0.35632
# [538]	validation_0-logloss:0.35631
# [539]	validation_0-logloss:0.35628
# [540]	validation_0-logloss:0.35627
# [541]	validation_0-logloss:0.35627
# [542]	validation_0-logloss:0.35624
# [543]	validation_0-logloss:0.35622
# [544]	validation_0-logloss:0.35621
# [545]	validation_0-logloss:0.35620
# [546]	validation_0-logloss:0.35619
# [547]	validation_0-logloss:0.35617
# [548]	validation_0-logloss:0.35616
# [549]	validation_0-logloss:0.35614
# [550]	validation_0-logloss:0.35613
# [551]	validation_0-logloss:0.35611
# [552]	validation_0-logloss:0.35608
# [553]	validation_0-logloss:0.35608
# [554]	validation_0-logloss:0.35606
# [555]	validation_0-logloss:0.35604
# [556]	validation_0-logloss:0.35603
# [557]	validation_0-logloss:0.35601
# [558]	validation_0-logloss:0.35598
# [559]	validation_0-logloss:0.35598
# [560]	validation_0-logloss:0.35596
# [561]	validation_0-logloss:0.35596
# [562]	validation_0-logloss:0.35595
# [563]	validation_0-logloss:0.35594
# [564]	validation_0-logloss:0.35593
# [565]	validation_0-logloss:0.35592
# [566]	validation_0-logloss:0.35590
# [567]	validation_0-logloss:0.35589
# [568]	validation_0-logloss:0.35588
# [569]	validation_0-logloss:0.35587
# [570]	validation_0-logloss:0.35587
# [571]	validation_0-logloss:0.35584
# [572]	validation_0-logloss:0.35584
# [573]	validation_0-logloss:0.35583
# [574]	validation_0-logloss:0.35581
# [575]	validation_0-logloss:0.35581
# [576]	validation_0-logloss:0.35579
# [577]	validation_0-logloss:0.35578
# [578]	validation_0-logloss:0.35577
# [579]	validation_0-logloss:0.35576
# [580]	validation_0-logloss:0.35576
# [581]	validation_0-logloss:0.35574
# [582]	validation_0-logloss:0.35574
# [583]	validation_0-logloss:0.35573
# [584]	validation_0-logloss:0.35572
# [585]	validation_0-logloss:0.35572
# [586]	validation_0-logloss:0.35570
# [587]	validation_0-logloss:0.35568
# [588]	validation_0-logloss:0.35566
# [589]	validation_0-logloss:0.35565
# [590]	validation_0-logloss:0.35565
# [591]	validation_0-logloss:0.35563
# [592]	validation_0-logloss:0.35562
# [593]	validation_0-logloss:0.35561
# [594]	validation_0-logloss:0.35560
# [595]	validation_0-logloss:0.35559
# [596]	validation_0-logloss:0.35558
# [597]	validation_0-logloss:0.35557
# [598]	validation_0-logloss:0.35556
# [599]	validation_0-logloss:0.35556
# [600]	validation_0-logloss:0.35555
# [601]	validation_0-logloss:0.35554
# [602]	validation_0-logloss:0.35554
# [603]	validation_0-logloss:0.35553
# [604]	validation_0-logloss:0.35552
# [605]	validation_0-logloss:0.35551
# [606]	validation_0-logloss:0.35551
# [607]	validation_0-logloss:0.35550
# [608]	validation_0-logloss:0.35549
# [609]	validation_0-logloss:0.35548
# [610]	validation_0-logloss:0.35548
# [611]	validation_0-logloss:0.35546
# [612]	validation_0-logloss:0.35546
# [613]	validation_0-logloss:0.35544
# [614]	validation_0-logloss:0.35543
# [615]	validation_0-logloss:0.35542
# [616]	validation_0-logloss:0.35541
# [617]	validation_0-logloss:0.35540
# [618]	validation_0-logloss:0.35540
# [619]	validation_0-logloss:0.35539
# [620]	validation_0-logloss:0.35538
# [621]	validation_0-logloss:0.35537
# [622]	validation_0-logloss:0.35536
# [623]	validation_0-logloss:0.35536
# [624]	validation_0-logloss:0.35535
# [625]	validation_0-logloss:0.35533
# [626]	validation_0-logloss:0.35533
# [627]	validation_0-logloss:0.35531
# [628]	validation_0-logloss:0.35530
# [629]	validation_0-logloss:0.35530
# [630]	validation_0-logloss:0.35529
# [631]	validation_0-logloss:0.35528
# [632]	validation_0-logloss:0.35527
# [633]	validation_0-logloss:0.35526
# [634]	validation_0-logloss:0.35524
# [635]	validation_0-logloss:0.35523
# [636]	validation_0-logloss:0.35523
# [637]	validation_0-logloss:0.35523
# [638]	validation_0-logloss:0.35522
# [639]	validation_0-logloss:0.35520
# [640]	validation_0-logloss:0.35520
# [641]	validation_0-logloss:0.35518
# [642]	validation_0-logloss:0.35518
# [643]	validation_0-logloss:0.35517
# [644]	validation_0-logloss:0.35517
# [645]	validation_0-logloss:0.35517
# [646]	validation_0-logloss:0.35516
# [647]	validation_0-logloss:0.35516
# [648]	validation_0-logloss:0.35516
# [649]	validation_0-logloss:0.35515
# [650]	validation_0-logloss:0.35515
# [651]	validation_0-logloss:0.35514
# [652]	validation_0-logloss:0.35514
# [653]	validation_0-logloss:0.35513
# [654]	validation_0-logloss:0.35513
# [655]	validation_0-logloss:0.35511
# [656]	validation_0-logloss:0.35510
# [657]	validation_0-logloss:0.35510
# [658]	validation_0-logloss:0.35509
# [659]	validation_0-logloss:0.35508
# [660]	validation_0-logloss:0.35507
# [661]	validation_0-logloss:0.35507
# [662]	validation_0-logloss:0.35505
# [663]	validation_0-logloss:0.35505
# [664]	validation_0-logloss:0.35504
# [665]	validation_0-logloss:0.35503
# [666]	validation_0-logloss:0.35502
# [667]	validation_0-logloss:0.35501
# [668]	validation_0-logloss:0.35501
# [669]	validation_0-logloss:0.35500
# [670]	validation_0-logloss:0.35500
# [671]	validation_0-logloss:0.35499
# [672]	validation_0-logloss:0.35498
# [673]	validation_0-logloss:0.35497
# [674]	validation_0-logloss:0.35496
# [675]	validation_0-logloss:0.35496
# [676]	validation_0-logloss:0.35495
# [677]	validation_0-logloss:0.35494
# [678]	validation_0-logloss:0.35494
# [679]	validation_0-logloss:0.35493
# [680]	validation_0-logloss:0.35492
# [681]	validation_0-logloss:0.35492
# [682]	validation_0-logloss:0.35491
# [683]	validation_0-logloss:0.35491
# [684]	validation_0-logloss:0.35490
# [685]	validation_0-logloss:0.35491
# [686]	validation_0-logloss:0.35490
# [687]	validation_0-logloss:0.35490
# [688]	validation_0-logloss:0.35489
# [689]	validation_0-logloss:0.35488
# [690]	validation_0-logloss:0.35488
# [691]	validation_0-logloss:0.35487
# [692]	validation_0-logloss:0.35485
# [1165]	validation_0-logloss:0.35401
# [1166]	validation_0-logloss:0.35402
# [1167]	validation_0-logloss:0.35402
# [1168]	validation_0-logloss:0.35401
# [1169]	validation_0-logloss:0.35401
# [1170]	validation_0-logloss:0.35401
# 0.8367730522591582
#               precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89     20411
#         True       0.71      0.59      0.64      6723
#
#     accuracy                           0.84     27134
#    macro avg       0.79      0.75      0.77     27134
# weighted avg       0.83      0.84      0.83     27134

# %% [markdown]
# ### LightGBM
# * XGBoost에 비해서 속도가 빠르고 메모리 사용량이 적음
# * 10,000건 이하의 크기가 작은 데이터 세트에서 과적합 발생 위험이 있음
# * 보통 트리기반 알고리즘은 균형 트리 분할을 사용해 트리간 균형을 맞추기 때문에 시간이 오래걸림
# * 라이트GBM은 Leaf중심 트리 분할을 사용하여 트리의 균형을 맞추지 않고 최대 손실값을 가지는 리프노드를 지속적으로 분할하면서 깊고 비대칭적인 트리생성

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(n_estimators= 1000, n_jobs=-1, learning_rate=0.01, random_state=10)
lgbm.fit(X_train, y_train)
pred_lgbm = lgbm.predict(X_test)
print(accuracy_score(y_test, pred_lgbm))
print(classification_report(y_test, pred_lgbm))
# Out:
# [LightGBM] [Info] Number of positive: 4485, number of negative: 13603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002627 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 147
# [LightGBM] [Info] Number of data points in the train set: 18088, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247954 -> initscore=-1.109552
# [LightGBM] [Info] Start training from score -1.109552
# 0.837289010098032
#               precision    recall  f1-score   support
#
#        False       0.87      0.92      0.89     20411
#         True       0.70      0.60      0.65      6723
#
#     accuracy                           0.84     27134
#    macro avg       0.79      0.76      0.77     27134
# weighted avg       0.83      0.84      0.83     27134

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators= 1000, n_jobs=-1, random_state=10)
rfc.fit(X_train, y_train)
pred_rfc = rfc.predict(X_test)
print(accuracy_score(y_test, pred_rfc))
print(classification_report(y_test, pred_rfc))
# Out:
# 0.8198201518390211
#               precision    recall  f1-score   support
#
#        False       0.86      0.91      0.88     20411
#         True       0.66      0.56      0.61      6723
#
#     accuracy                           0.82     27134
#    macro avg       0.76      0.73      0.74     27134
# weighted avg       0.81      0.82      0.81     27134

# %% [markdown]
# ### ExtraTreesClassifier
# * 랜덤포레스트와 비슷하지만 후보 특성을 무작위로 분할 한 다음 최적의 분할 탐색
# * 부트스트랩 샘플링은 사용하지 않음
# * 무작위성 증가 => 모델의 편향은 늘어나지만 분산이 감소

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators= 1000, n_jobs=-1, random_state=10)
etc.fit(X_train, y_train)
pred_etc = etc.predict(X_test)
print(accuracy_score(y_test, pred_etc))
print(classification_report(y_test, pred_etc))
# Out:
# 0.8121913466499595
#               precision    recall  f1-score   support
#
#        False       0.85      0.91      0.88     20411
#         True       0.65      0.53      0.58      6723
#
#     accuracy                           0.81     27134
#    macro avg       0.75      0.72      0.73     27134
# weighted avg       0.80      0.81      0.81     27134
