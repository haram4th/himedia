# %% [markdown]
# # 2. 변수, 자료형, 연산자

# %% [markdown]
# ## 1) 변수(variable)란?

# %% [markdown]
# ![Alt text](./vaiables.png)

# %% [markdown]
# ### 변수 = 자료를 넣는 상자

# %% [markdown]
# ### 어떤 자료를 담느냐에 따라 가방의 모양/성격(자료형)이 달라짐

# %%
a = 4
b = 2.5
c = 'a'
d = "hello"

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
print(type(d))
# Out:
# <class 'str'>

# %% [markdown]
# ### 변수 여러 개를 한 번에 만들기 (변수 갯수와 데이터 갯수는 일치시켜야 함)

# %%
x, y, z = 10, 20, 30

# %%
sum = x + y + z

# %% [markdown]
# ### 변수 삭제하기

# %%
del x

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
x=10
x=20
x=30
x
# Out:
# 30

# %% [markdown]
# ### 입력값 변수에 저장하기 input() 함수사용

# %% [markdown]
# input() 함수를 사용하면 문자열을 입력받아 변수에 저장 가능

# %%
num = input()
# Out:
# 10

# %%
print(num)
# Out:
# 10

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
num1, num2, num3 = input().split()
# Out:
# 20 30 40

# %%
print(num1, num2, num3)
# Out:
# 20 30 40

# %%
sum = num1 + num2 + num3
sum
# Out:
# '203040'

# %% [markdown]
# ## 2) 자료형(Data Type)이란?

# %%
### 변수에 담기는 자료의 형태에 따라서 자료형이 달라짐

# %% [markdown]
# ### 정수형(int, integer) 변수

# %%
x = 10
x
# Out:
# 10

# %% [markdown]
# ### 실수형(float) 변수

# %%
y = 3.14
y
# Out:
# 3.14

# %% [markdown]
# ### 문자형(str, integer) 변수

# %%
s = "문자형 변수"
s
# Out:
# '문자형 변수'

# %%
s2 = '문자형 변수2'
s2
# Out:
# '문자형 변수2'

# %%
s3 = '''문자형 변수에는 단어 뿐만 아니라 문장도 들어갈 수 있다.'''
s3
# Out:
# '문자형 변수에는 단어 뿐만 아니라 문장도 들어갈 수 있다.'

# %%
s4 = """문자형 변수에는 단어 뿐만 아니라 문장도 들어갈 수 있고
여러개의 문장이 모두 들어갈 수 있다.
메모리가 허용하는 한도 내에서 변수 한 개에 저장되는 데이터는 크기는 제한이 없다."""
s4
# Out:
# '문자형 변수에는 단어 뿐만 아니라 문장도 들어갈 수 있고\n여러개의 문장이 모두 들어갈 수 있다.\n메모리가 허용하는 한도 내에서 변수 한 개에 저장되는 데이터는 크기는 제한이 없다.'

# %% [markdown]
# ### 리스트형(list) 변수 - 데이터 분석에서 가장 많이 사용 되는 자료형1

# %% [markdown]
# 데이터 분석시 자료를 다룰 때 가장 많이 활용하게 되는 데이터형이므로 반드시 사용법을 잘 익혀둬야 한다.

# %% [markdown]
# 리스트에는 정수, 실수, 문자 모두가 들어갈 수 있다.

# %%
L = [1,3,9,"파이썬",'경복대',9.6]
print(L)
print(type(l))
# Out:
# [1, 3, 9, '파이썬', '경복대', 9.6]
# <class 'list'>

# %% [markdown]
# 리스트 안에 리스트가 들어가는 것도 가능

# %%
L2 = [1,[1,2],"파이썬", '신기해', [3.5, '다 되네']]
L2
# Out:
# [1, [1, 2], '파이썬', '신기해', [3.5, '다 되네']]

# %% [markdown]
# 리스트 안에 튜플, 딕셔너리가 포함되어 있어도 가능

# %%
L3 = [1, (5,6,7), {'subject' : 'python', 'univ' : 'kyungbok' }, "튜플도", '딕셔너리도 가능', 2222, 9.6 ]
L3
# Out:
# [1,
#  (5, 6, 7),
#  {'subject': 'python', 'univ': 'kyungbok'},
#  '튜플도',
#  '딕셔너리도 가능',
#  2222,
#  9.6]

# %% [markdown]
# ### 튜플형(Tupple) 변수

# %% [markdown]
# 리스트처럼 다양한 자료를 넣을 수 있고 사용법도 거의 동일, 차이점은 만들어진 튜플의 값은 변경 불가능

# %% [markdown]
# 자료의 변경이 되면 안될 때 주로 사용

# %%
T = (1,2,3,4,5,6)
T
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
T2 = (1, (5,6,7), {'subject' : 'python', 'univ' : 'kyungbok' }, "튜플은", '리스트와 유사', '내용 변경이 안됨', 2222, 9.6 )
T2
# Out:
# (1,
#  (5, 6, 7),
#  {'subject': 'python', 'univ': 'kyungbok'},
#  '튜플은',
#  '리스트와 유사',
#  '내용 변경이 안됨',
#  2222,
#  9.6)

# %% [markdown]
# ### 딕셔너리형(Dictionary) 변수 JSON(제이슨) 형이라고도 함 - 데이터 분석에서 가장 많이 사용되는 자료형2

# %% [markdown]
# Key : Value 형태의 자료형으로 나중에 API를 이용해 자료를 수집하면 대부분 JSON(Python에서 딕셔너리) 형태로 받게 되므로 반드시 사용법에 익숙해져야한다.

# %%
D = {'년월' : '202002', '국가' : '미국', '방문자수' : 1000 }
D
# Out:
# {'년월': '202002', '국가': '미국', '방문자수': 1000}

# %%
D['년월']
# Out:
# '202002'

# %%
D['국가']
# Out:
# '미국'

# %%
D['방문자수']
# Out:
# 1000
